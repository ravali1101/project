# %%
import pandas as pd
import hashlib
import numpy as np

# %% [markdown]
# ### read excel sheet

# %%
sheet1= pd.read_excel('placements-sois.xlsx',sheetname='PlacementStats')

# %%
sheet2= pd.read_excel('placements-sois.xlsx',sheetname='Enrollment')

# %%
sheet1_reindexing=sheet1.reset_index()
sheet1_reindexing
# Out:
#      index                        As on 2015 Mar 17      Unnamed: 1  \
# 0      NaN                                      NaN             NaN
# 1      NaN                         ME / MSc Program         2015_01
# 2      NaN                                      NaN  Class Strength
# 3      NaN                         Medical Software               0
# 4      NaN                              VLSI Design               0
# 5      NaN                         Embedded Systems               6
# 6      NaN         Embedded & Wireless Technologies               0
# 7      NaN  Computing Technologies & Virtualization               0
# 8      NaN                      Information Science               7
# 9      NaN          Embedded & Instrumentation Engg               0
# 10     NaN              Automotive Embedded Systems               0
# 11     NaN                           Total Strength             NaN
# 12     NaN              All branch without ESIGELEC              13
# 13     NaN                             All branches              13
# 14     NaN                                      NaN             NaN
# 15     NaN                        As on 2015 Mar 17             NaN
# 16     NaN                                      NaN             NaN
# 17     NaN                         MSc Tech Program         2014_01
# 18     NaN                                      NaN  Class Strength
# 19     NaN                         Medical Software               0
# 20     NaN                              VLSI Design               0
# 21     NaN                         Embedded Systems              13
# 22     NaN         Embedded & Wireless Technologies               0
# 23     NaN  Computing Technologies & Virtualization               0
# 24     NaN        VLSI System Design & Verification               0
# 25     NaN          Embedded & Instrumentation Engg               0
# 26     NaN                           Total Strength             NaN
# 27     NaN       All branch without ESIGELEC n VSDV              13
# 28     NaN  All branch without ESIGELEC n with VSDV              13
# 29     NaN                             All branches              13
# ..     ...                                      ...             ...
# 145    NaN                                      NaN             NaN
# 146    NaN                                      NaN             NaN
# 147    NaN                        As on 2006 Dec 31             NaN
# 148    NaN                                      NaN             NaN
# 149    NaN                               MS Program         2005_01
# 150    NaN                                      NaN  Class Strength
# 151    NaN                         Medical Software               0
# 152    NaN                                 VLSI CAD               6
# 153    NaN                         Embedded Systems              11
# 154    NaN                           Total Strength             NaN
# 155    NaN                                      NaN             NaN
# 156    NaN                                      NaN             NaN
# 157    NaN                        As on 2005 Dec 31             NaN
# 158    NaN                                      NaN             NaN
# 159    NaN                               MS Program         2004_01
# 160    NaN                                      NaN  Class Strength
# 161    NaN                         Medical Software               6
# 162    NaN                                 VLSI CAD               2
# 163    NaN                         Embedded Systems               8
# 164    NaN                           Total Strength             NaN
# 165    NaN                                      NaN             NaN
# 166    NaN                                      NaN             NaN
# 167    NaN                        As on 2004 Dec 31             NaN
# 168    NaN                                      NaN             NaN
# 169    NaN                               MS Program         2003_01
# 170    NaN                                      NaN  Class Strength
# 171    NaN                         Medical Software              15
# 172    NaN                                 VLSI CAD              10
# 173    NaN                         Embedded Systems              10
# 174    NaN                           Total Strength             NaN
#
#               Unnamed: 2      Unnamed: 3      Unnamed: 4           Unnamed: 5  \
# 0                    NaN             NaN             NaN                  NaN
# 1                    NaN             NaN         2015_08                  NaN
# 2    # of Placed Student  Self Placement  Class Strength  # of Placed Student
# 3                      0               0               8                    6
# 4                      0               0              38                   21
# 5                      5               0              43                   32
# 6                      0               0               9                    6
# 7                      0               0              10                    6
# 8                      6               1               0                    0
# 9                      0               0              12                   12
# 10                     0               0              11                   11
# 11                   NaN             NaN             NaN                  NaN
# 12                    11               1             108                   71
# 13                    11               1             131                   94
# 14                   NaN             NaN             NaN                  NaN
# 15                   NaN             NaN             NaN                  NaN
# 16                   NaN             NaN             NaN                  NaN
# 17                   NaN             NaN         2014_08                  NaN
# 18   # of Placed Student             NaN  Class Strength  # of Placed Student
# 19                     0             NaN              14                   12
# 20                     0             NaN              41                   30
# 21                    13             NaN              68                   57
# 22                     0             NaN              11                   11
# 23                     0             NaN               8                    7
# 24                     0             NaN               4                    4
# 25                     0             NaN              25                   25
# 26                   NaN             NaN             NaN                  NaN
# 27                    13             NaN             142                  117
# 28                    13             NaN             146                  121
# 29                    13             NaN             171                  146
# ..                   ...             ...             ...                  ...
# 145                  NaN             NaN             NaN                  NaN
# 146                  NaN             NaN             NaN                  NaN
# 147                  NaN             NaN             NaN                  NaN
# 148                  NaN             NaN             NaN                  NaN
# 149                  NaN             NaN         2005_08                  NaN
# 150  # of Placed Student             NaN  Class Strength  # of Placed Student
# 151                    0             NaN              11                   11
# 152                    4             NaN              27                   19
# 153                    7             NaN              39                   32
# 154                  NaN             NaN             NaN                  NaN
# 155                  NaN             NaN             NaN                  NaN
# 156                  NaN             NaN             NaN                  NaN
# 157                  NaN             NaN             NaN                  NaN
# 158                  NaN             NaN             NaN                  NaN
# 159                  NaN             NaN         2004_08                  NaN
# 160  # of Placed Student             NaN  Class Strength  # of Placed Student
# 161                    5             NaN              10                    7
# 162                    2             NaN              25                   20
# 163                    6             NaN              20                   10
# 164                  NaN             NaN             NaN                  NaN
# 165                  NaN             NaN             NaN                  NaN
# 166                  NaN             NaN             NaN                  NaN
# 167                  NaN             NaN             NaN                  NaN
# 168                  NaN             NaN             NaN                  NaN
# 169                  NaN             NaN         2003_08                  NaN
# 170  # of Placed Student             NaN  Class Strength  # of Placed Student
# 171                    6             NaN              16                    7
# 172                    5             NaN              19                   15
# 173                    5             NaN              29                   17
# 174                  NaN             NaN             NaN                  NaN
#
#          Unnamed: 6      Unnamed: 7           Unnamed: 8      Unnamed: 9  \
# 0               NaN             NaN                  NaN             NaN
# 1               NaN           Total                  NaN             NaN
# 2    Self Placement  Class Strength  # of Placed Student  Self Placement
# 3                 0               8                    6               0
# 4                 0              38                   23               1
# 5                 0              49                   38               0
# 6                 1               9                    6               1
# 7                 2              10                    6               2
# 8                 0               7                    6               1
# 9                 0              12                   12               0
# 10                0              11                   11               0
# 11              NaN             NaN                  NaN             NaN
# 12                3             121                   85               4
# 13                3             144                  108               4
# 14              NaN             NaN                  NaN             NaN
# 15              NaN             NaN                  NaN             NaN
# 16              NaN             NaN                  NaN             NaN
# 17              NaN           Total                  NaN             NaN
# 18              NaN  Class Strength  # of Placed Student             NaN
# 19              NaN              14                   12             NaN
# 20              NaN              41                   30             NaN
# 21              NaN              81                   70             NaN
# 22              NaN              11                   11             NaN
# 23              NaN               8                    7             NaN
# 24              NaN               4                    4             NaN
# 25              NaN              25                   25             NaN
# 26              NaN             NaN                  NaN             NaN
# 27              NaN             155                  130             NaN
# 28              NaN             159                  134             NaN
# 29              NaN             184                  159             NaN
# ..              ...             ...                  ...             ...
# 145             NaN             NaN                  NaN             NaN
# 146             NaN             NaN                  NaN             NaN
# 147             NaN             NaN                  NaN             NaN
# 148             NaN             NaN                  NaN             NaN
# 149             NaN           Total                  NaN             NaN
# 150             NaN  Class Strength  # of Placed Student             NaN
# 151             NaN              11                   11             NaN
# 152             NaN              33                   23             NaN
# 153             NaN              50                   39             NaN
# 154             NaN              94                   73             NaN
# 155             NaN             NaN                  NaN             NaN
# 156             NaN             NaN                  NaN             NaN
# 157             NaN             NaN                  NaN             NaN
# 158             NaN             NaN                  NaN             NaN
# 159             NaN           Total                  NaN             NaN
# 160             NaN  Class Strength  # of Placed Student             NaN
# 161             NaN              16                   12             NaN
# 162             NaN              27                   22             NaN
# 163             NaN              28                   16             NaN
# 164             NaN              71                   50             NaN
# 165             NaN             NaN                  NaN             NaN
# 166             NaN             NaN                  NaN             NaN
# 167             NaN             NaN                  NaN             NaN
# 168             NaN             NaN                  NaN             NaN
# 169             NaN           Total                  NaN             NaN
# 170             NaN  Class Strength  # of Placed Student             NaN
# 171             NaN              31                   13             NaN
# 172             NaN              29                   20             NaN
# 173             NaN              39                   22             NaN
# 174             NaN              99                   55             NaN
#
#     Unnamed: 10
# 0           NaN
# 1             %
# 2           NaN
# 3            75
# 4       63.1579
# 5        77.551
# 6       77.7778
# 7            80
# 8           100
# 9           100
# 10          100
# 11          NaN
# 12      73.5537
# 13      77.7778
# 14          NaN
# 15          NaN
# 16          NaN
# 17            %
# 18          NaN
# 19      85.7143
# 20      73.1707
# 21      86.4198
# 22          100
# 23         87.5
# 24          100
# 25          100
# 26          NaN
# 27       83.871
# 28      84.2767
# 29       86.413
# ..          ...
# 145         NaN
# 146         NaN
# 147         NaN
# 148         NaN
# 149           %
# 150         NaN
# 151         100
# 152      69.697
# 153          78
# 154     77.6596
# 155         NaN
# 156         NaN
# 157         NaN
# 158         NaN
# 159           %
# 160         NaN
# 161          75
# 162     81.4815
# 163     57.1429
# 164     70.4225
# 165         NaN
# 166         NaN
# 167         NaN
# 168         NaN
# 169           %
# 170         NaN
# 171     41.9355
# 172     68.9655
# 173     56.4103
# 174     55.5556
#
# [175 rows x 12 columns]

# %% [markdown]
# ### create data frames for placements sheet

# %%
df1=sheet1_reindexing[2:14]

# %%
df1.columns = df1.iloc[0]

# %%
df1=df1.reindex(df1.index.drop(2))

# %%
df1['year_intake']= 2015

# %%
df1=df1.ix[:,1:13]

# %%
df1=df1.reindex(df1.index.delete(8))

# %%
df1.columns = ['Branches','Class Strength_1','# of placed students_1','Self Placement_1','Class Strength_8','# of placed students_8','Self Placement_8','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']

# %%
df1.columns
df1 = df1.reset_index()
del df1['index']

# %%
df1
# Out:
#                                   Branches Class Strength_1  \
# 0                         Medical Software                0
# 1                              VLSI Design                0
# 2                         Embedded Systems                6
# 3         Embedded & Wireless Technologies                0
# 4  Computing Technologies & Virtualization                0
# 5                      Information Science                7
# 6          Embedded & Instrumentation Engg                0
# 7              Automotive Embedded Systems                0
# 8              All branch without ESIGELEC               13
# 9                             All branches               13
#
#   # of placed students_1 Self Placement_1 Class Strength_8  \
# 0                      0                0                8
# 1                      0                0               38
# 2                      5                0               43
# 3                      0                0                9
# 4                      0                0               10
# 5                      6                1                0
# 6                      0                0               12
# 7                      0                0               11
# 8                     11                1              108
# 9                     11                1              131
#
#   # of placed students_8 Self Placement_8 Class Strength # of placed students  \
# 0                      6                0              8                    6
# 1                     21                0             38                   23
# 2                     32                0             49                   38
# 3                      6                1              9                    6
# 4                      6                2             10                    6
# 5                      0                0              7                    6
# 6                     12                0             12                   12
# 7                     11                0             11                   11
# 8                     71                3            121                   85
# 9                     94                3            144                  108
#
#   Self Placement Total placement %  year_intake
# 0              0                75         2015
# 1              1           63.1579         2015
# 2              0            77.551         2015
# 3              1           77.7778         2015
# 4              2                80         2015
# 5              1               100         2015
# 6              0               100         2015
# 7              0               100         2015
# 8              4           73.5537         2015
# 9              4           77.7778         2015

# %%
df2=sheet1_reindexing[18:30]

# %%
df2.columns = df2.iloc[0]

# %%
df2=df2.reindex(df2.index.drop(18))

# %%
df2['year_intake']= 2014

# %%
df2=df2.ix[:,1:13]

# %%
df2 = df2.reset_index()

# %%
del df2['index']

# %%
df2=df2.reindex(df2.index.delete(7))

# %%
df2.columns = ['Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']

# %%
df2.columns
# Out:
# Index(['Branches', 'Class Strength_1', '# of placed students_1',
#        'Self Placement', 'Class Strength_8', '# of placed students_8',
#        'Self Placement', 'Class Strength', '# of placed students',
#        'Self Placement', 'Total placement %', 'year_intake'],
#       dtype='object')

# %%
df2=df2.drop("Self Placement",axis=1)
df2 = df2.reset_index()
del df2['index']

# %%
df3=sheet1_reindexing[34:45]

# %%
df3.columns = df3.iloc[0]

# %%
df3=df3.reindex(df3.index.drop(34))

# %%
df3['year_intake']= 2013

# %%
df3=df3.ix[:,1:13]

# %%
df3 = df3.reset_index()

# %%
del df3['index']

# %%
df3.columns = ['Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']

# %%
df3.columns
# Out:
# Index(['Branches', 'Class Strength_1', '# of placed students_1',
#        'Self Placement', 'Class Strength_8', '# of placed students_8',
#        'Self Placement', 'Class Strength', '# of placed students',
#        'Self Placement', 'Total placement %', 'year_intake'],
#       dtype='object')

# %%
df3.loc[8,'Class Strength_1'] = 32

# %%
df3.loc[8,'# of placed students_1'] = 30

# %%
df3.loc[8,'Class Strength_8'] = 151

# %%
df3.loc[8,'# of placed students_8'] = 146

# %%
df3.drop([9])
# Out:
#                                   Branches Class Strength_1  \
# 0                         Medical Software                0
# 1                              VLSI Design               13
# 2         Embedded Systems - BE/Btech Grad               19
# 3          Embedded Systems - BCA/BSc Grad                0
# 4        VLSI System Design & Verification                0
# 5         Embedded & Wireless Technologies                0
# 6                            IT Management                0
# 7  Computing Technologies & Virtualization                0
# 8                           Total Strength               32
#
#   # of placed students_1 Self Placement Class Strength_8  \
# 0                      0            NaN               12
# 1                     12            NaN               29
# 2                     18            NaN               84
# 3                      0            NaN                5
# 4                      0            NaN                6
# 5                      0            NaN               12
# 6                      0            NaN                3
# 7                      0            NaN                0
# 8                     30            NaN              151
#
#   # of placed students_8 Self Placement Class Strength # of placed students  \
# 0                     12            NaN             12                   12
# 1                     28            NaN             42                   40
# 2                     81            NaN            103                   99
# 3                      5            NaN              5                    5
# 4                      6            NaN              6                    6
# 5                     11            NaN             12                   11
# 6                      3            NaN              3                    3
# 7                      0            NaN              0                    0
# 8                    146            NaN            183                  176
#
#   Self Placement Total placement %  year_intake
# 0            NaN               100         2013
# 1            NaN           95.2381         2013
# 2            NaN           96.1165         2013
# 3            NaN               100         2013
# 4            NaN               100         2013
# 5            NaN           91.6667         2013
# 6            NaN               100         2013
# 7            NaN               NaN         2013
# 8            NaN           96.1749         2013

# %%
df3=df3.drop("Self Placement",axis=1)
df3 = df3.reset_index()
del df3['index']

# %%
df4=sheet1_reindexing[50:61]

# %%
df4.columns = df4.iloc[0]

# %%
df4=df4.reindex(df4.index.drop(50))

# %%
df4['year_intake']= 2012

# %%
df4 = df4.reset_index()

# %%
del df4['index']

# %%
df4.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']

# %%
df4.columns
# Out:
# Index(['nan1', 'Branches', 'Class Strength_1', '# of placed students_1',
#        'Self Placement', 'Class Strength_8', '# of placed students_8',
#        'Self Placement', 'Class Strength', '# of placed students',
#        'Self Placement', 'Total placement %', 'year_intake'],
#       dtype='object')

# %%
df4=df4.drop("Self Placement",axis=1)

# %%
df4=df4.drop("nan1",axis=1)
df4 = df4.reset_index()
del df4['index']

# %%
df5=sheet1_reindexing[66:77]

# %%
df5.columns = df5.iloc[0]

# %%
df5=df5.reindex(df5.index.drop(66))

# %%
df5['year_intake']= 2011

# %%
df5 = df5.reset_index()

# %%
del df5['index']

# %%
df5.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']

# %%
df5=df5.drop("Self Placement",axis=1)

# %%
df5=df5.drop("nan1",axis=1)
df5 = df5.reset_index()
del df5['index']

# %%
df6=sheet1_reindexing[83:92]

# %%
df6.columns = df6.iloc[0]

# %%
df6=df6.reindex(df6.index.drop(83))

# %%
df6['year_intake']= 2010

# %%
df6 = df6.reset_index()

# %%
del df6['index']

# %%
df6.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']

# %%
df6=df6.drop("Self Placement",axis=1)

# %%
df6=df6.drop("nan1",axis=1)
df6 = df6.reset_index()
del df6['index']

# %%
df7=sheet1_reindexing[98:106]

# %%
df7.columns = df7.iloc[0]

# %%
df7=df7.reindex(df7.index.drop(98))

# %%
df7['year_intake']= 2009

# %%
df7 = df7.reset_index()

# %%
del df7['index']

# %%
df7.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']

# %%
df7=df7.drop("Self Placement",axis=1)

# %%
df7=df7.drop("nan1",axis=1)
df7 = df7.reset_index()
del df7['index']

# %%
df8=sheet1_reindexing[112:120]

# %%
df8.columns = df8.iloc[0]
df8=df8.reindex(df8.index.drop(112))
df8['year_intake']= 2008
df8 = df8.reset_index()
del df8['index']
df8.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']
df8=df8.drop("Self Placement",axis=1)
df8=df8.drop("nan1",axis=1)
df8 = df8.reset_index()
del df8['index']

# %%
df9=sheet1_reindexing[126:133]

# %%
df9.columns = df9.iloc[0]
df9=df9.reindex(df9.index.drop(126))
df9['year_intake']= 2007
df9 = df9.reset_index()
del df9['index']
df9.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']
df9=df9.drop("Self Placement",axis=1)
df9=df9.drop("nan1",axis=1)

# %%
df10=sheet1_reindexing[138:145]

# %%
df10.columns = df10.iloc[0]
df10=df10.reindex(df10.index.drop(138))
df10['year_intake']= 2006
df10 = df10.reset_index()
del df10['index']
df10.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']
df10=df10.drop("Self Placement",axis=1)
df10=df10.drop("nan1",axis=1)

# %%
df11=sheet1_reindexing[150:155]

# %%
df11.columns = df11.iloc[0]
df11=df11.reindex(df11.index.drop(150))
df11['year_intake']= 2005
df11 = df11.reset_index()
del df11['index']
df11.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']
df11=df11.drop("Self Placement",axis=1)
df11=df11.drop("nan1",axis=1)

# %%
df12=sheet1_reindexing[160:165]

# %%
df12.columns = df12.iloc[0]
df12=df12.reindex(df12.index.drop(160))
df12['year_intake']= 2004
df12 = df12.reset_index()
del df12['index']
df12.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']
df12=df12.drop("Self Placement",axis=1)
df12=df12.drop("nan1",axis=1)

# %%
df13=sheet1_reindexing[170:176]

# %%
df13.columns = df13.iloc[0]
df13=df13.reindex(df13.index.drop(170))
df13['year_intake']= 2003
df13 = df13.reset_index()
del df13['index']
df13.columns = ['nan1','Branches','Class Strength_1','# of placed students_1','Self Placement','Class Strength_8','# of placed students_8','Self Placement','Class Strength','# of placed students','Self Placement','Total placement %','year_intake']
df13=df13.drop("Self Placement",axis=1)
df13=df13.drop("nan1",axis=1)

# %% [markdown]
# ### create data frames for enrollment sheet

# %%
enroll_1=sheet2[3:35]
enroll_1
# Out:
#    Manipal Centre for Information Sceince, Manipal Unnamed: 1  \
# 3                                               NO    ROLL NO
# 4                                                1  991073001
# 5                                                2  991073002
# 6                                                3  991073003
# 7                                                4  991073004
# 8                                                5  991073005
# 9                                                6  991073006
# 10                                               7  991073007
# 11                                               8  991073008
# 12                                               9  991073009
# 13                                              10  991073010
# 14                                              11  991073011
# 15                                              12  991073012
# 16                                              13  991073013
# 17                                              14  991073014
# 18                                              15  991073015
# 19                                              16  991073016
# 20                                              17  991073017
# 21                                              18  991073018
# 22                                              19  991073019
# 23                                              20  991073020
# 24                                              21  991073021
# 25                                              22  991073022
# 26                                              23  991073023
# 27                                              24  991073024
# 28                                              25  991073025
# 29                                              26  991073026
# 30                                              27  991073027
# 31                                              28  991073028
# 32                                              29  991073029
# 33                                              30  991073030
# 34                                              31  991073031
#
#                   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 3                       NAME        Sex      State        NaN
# 4     RAJESH SHENOY UDYAVARA          M        KAN        NaN
# 5                PADMAPRASAD          M        KAN        NaN
# 6            LINDA ANNE PAUL          F        KEL        NaN
# 7             SNIGDHA SAXENA          F        DEL        NaN
# 8        A GANESH SUBRAMANYA          M        KEL        NaN
# 9           SUDHESH D KAMATH          M        KAN        NaN
# 10                SULAKSHANA          F        KAN        NaN
# 11                 PRADEEP N          M        KAN        NaN
# 12          KARUNAKARA RAI B          M        KAN        NaN
# 13           GOPALAKRISHNA K          M        KAN        NaN
# 14            SHREELATHA K V          F         AP        NaN
# 15          M KRISHNA PRASAD          M        KAN        NaN
# 16            PRIYESH KANNAN          M        KEL        NaN
# 17       R BRIJESH PRABHAKAR          M        TAM        NaN
# 18                 ASHA PAUL          F        KEL        NaN
# 19      ELMA CLARABELL SOANS          F        KAN        NaN
# 20         ASHUTHOSH RUSTOGI          M        DEL        NaN
# 21         G SEETHARAM GUPTA          M         AP        NaN
# 22        VIJAYA KRISHNA M R          M        KAR        NaN
# 23                   VINOD A          M        KEL        NaN
# 24          JOJO VITHAYATHIL          M        KEL        NaN
# 25                 TOM TILLO          M        KEL        NaN
# 26           JIMJEES ABRAHAM          M        KEL        NaN
# 27          JEITENDER BHATIA          M        DEL        NaN
# 28            KALPANA SHARMA          F        DEL        NaN
# 29            V LAKSHMI KALA          F         AP        NaN
# 30          MADHURA NAVADA P          F        KAN        NaN
# 31              BHASKAR GOSH          M         WB        NaN
# 32  SHETTY MANOJ BALAKRISHNA          M        KAN        NaN
# 33            ASHOK R SHETTY          M        KAN        NaN
# 34      B RAGHAVENDRA AITHAL          M        KAN        NaN

# %%
#enroll_1.loc[:, 'colyear'] = '1999 to '
enroll_1.loc[:,'year'] = 'Aug 1999 to Feb 2001'
#enroll_1.is_copy = True
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
enroll_1['Batch']='Batch_1'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
enroll_1['Branch']='MS Ecommerce'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
enroll_1.columns = enroll_1.iloc[0]

# %%
enroll_1=enroll_1.reindex(enroll_1.index.drop(3))

# %%
enroll_1 = enroll_1.reset_index()
del enroll_1['index']

# %%
enroll_1.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

# %%
enroll_1=enroll_1.drop("nan",axis=1)

# %%
enroll_1=enroll_1.set_index('NO')
enroll_1
# Out:
#       ROLL NO                      NAME Gender State                  Year  \
# NO
# 1   991073001    RAJESH SHENOY UDYAVARA      M   KAN  Aug 1999 to Feb 2001
# 2   991073002               PADMAPRASAD      M   KAN  Aug 1999 to Feb 2001
# 3   991073003           LINDA ANNE PAUL      F   KEL  Aug 1999 to Feb 2001
# 4   991073004            SNIGDHA SAXENA      F   DEL  Aug 1999 to Feb 2001
# 5   991073005       A GANESH SUBRAMANYA      M   KEL  Aug 1999 to Feb 2001
# 6   991073006          SUDHESH D KAMATH      M   KAN  Aug 1999 to Feb 2001
# 7   991073007                SULAKSHANA      F   KAN  Aug 1999 to Feb 2001
# 8   991073008                 PRADEEP N      M   KAN  Aug 1999 to Feb 2001
# 9   991073009          KARUNAKARA RAI B      M   KAN  Aug 1999 to Feb 2001
# 10  991073010           GOPALAKRISHNA K      M   KAN  Aug 1999 to Feb 2001
# 11  991073011            SHREELATHA K V      F    AP  Aug 1999 to Feb 2001
# 12  991073012          M KRISHNA PRASAD      M   KAN  Aug 1999 to Feb 2001
# 13  991073013            PRIYESH KANNAN      M   KEL  Aug 1999 to Feb 2001
# 14  991073014       R BRIJESH PRABHAKAR      M   TAM  Aug 1999 to Feb 2001
# 15  991073015                 ASHA PAUL      F   KEL  Aug 1999 to Feb 2001
# 16  991073016      ELMA CLARABELL SOANS      F   KAN  Aug 1999 to Feb 2001
# 17  991073017         ASHUTHOSH RUSTOGI      M   DEL  Aug 1999 to Feb 2001
# 18  991073018         G SEETHARAM GUPTA      M    AP  Aug 1999 to Feb 2001
# 19  991073019        VIJAYA KRISHNA M R      M   KAR  Aug 1999 to Feb 2001
# 20  991073020                   VINOD A      M   KEL  Aug 1999 to Feb 2001
# 21  991073021          JOJO VITHAYATHIL      M   KEL  Aug 1999 to Feb 2001
# 22  991073022                 TOM TILLO      M   KEL  Aug 1999 to Feb 2001
# 23  991073023           JIMJEES ABRAHAM      M   KEL  Aug 1999 to Feb 2001
# 24  991073024          JEITENDER BHATIA      M   DEL  Aug 1999 to Feb 2001
# 25  991073025            KALPANA SHARMA      F   DEL  Aug 1999 to Feb 2001
# 26  991073026            V LAKSHMI KALA      F    AP  Aug 1999 to Feb 2001
# 27  991073027          MADHURA NAVADA P      F   KAN  Aug 1999 to Feb 2001
# 28  991073028              BHASKAR GOSH      M    WB  Aug 1999 to Feb 2001
# 29  991073029  SHETTY MANOJ BALAKRISHNA      M   KAN  Aug 1999 to Feb 2001
# 30  991073030            ASHOK R SHETTY      M   KAN  Aug 1999 to Feb 2001
# 31  991073031      B RAGHAVENDRA AITHAL      M   KAN  Aug 1999 to Feb 2001
#
#       Batch        Branch
# NO
# 1   Batch_1  MS Ecommerce
# 2   Batch_1  MS Ecommerce
# 3   Batch_1  MS Ecommerce
# 4   Batch_1  MS Ecommerce
# 5   Batch_1  MS Ecommerce
# 6   Batch_1  MS Ecommerce
# 7   Batch_1  MS Ecommerce
# 8   Batch_1  MS Ecommerce
# 9   Batch_1  MS Ecommerce
# 10  Batch_1  MS Ecommerce
# 11  Batch_1  MS Ecommerce
# 12  Batch_1  MS Ecommerce
# 13  Batch_1  MS Ecommerce
# 14  Batch_1  MS Ecommerce
# 15  Batch_1  MS Ecommerce
# 16  Batch_1  MS Ecommerce
# 17  Batch_1  MS Ecommerce
# 18  Batch_1  MS Ecommerce
# 19  Batch_1  MS Ecommerce
# 20  Batch_1  MS Ecommerce
# 21  Batch_1  MS Ecommerce
# 22  Batch_1  MS Ecommerce
# 23  Batch_1  MS Ecommerce
# 24  Batch_1  MS Ecommerce
# 25  Batch_1  MS Ecommerce
# 26  Batch_1  MS Ecommerce
# 27  Batch_1  MS Ecommerce
# 28  Batch_1  MS Ecommerce
# 29  Batch_1  MS Ecommerce
# 30  Batch_1  MS Ecommerce
# 31  Batch_1  MS Ecommerce

# %%
enroll_2=sheet2[35:47]

# %%
enroll_2.loc[:,'year'] = ' Feb 2000 to Aug 2001'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
enroll_2['Batch']='Batch_2'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
enroll_2['Branch']='MS Ecommerce'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
enroll_2.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

# %%
enroll_2=enroll_2.reindex(enroll_2.index.drop(35))

# %%
enroll_2 = enroll_2.reset_index()

# %%
del enroll_2['index']

# %%
enroll_2=enroll_2.drop("nan",axis=1)

# %%
enroll_2=enroll_2.set_index('NO')

# %%
enroll_2.to_csv('enroll.csv')

# %%
enroll_3=sheet2[47:72]

# %%
enroll_3.loc[:,'year'] = 'Aug 2000 to Feb 2002'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
enroll_3['Batch']='Batch_3'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
enroll_3['Branch']='MS Ecommerce'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
enroll_3.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

# %%
enroll_3=enroll_3.reindex(enroll_3.index.drop(47))

# %%
enroll_3 = enroll_3.reset_index()

# %%
del enroll_3['index']

# %%
enroll_3=enroll_3.drop("nan",axis=1)

# %%
enroll_3=enroll_3.set_index('NO')

# %%
enroll_4=sheet2[73:78]

# %%
enroll_4.loc[:,'year'] = 'Feb 2001 to Aug 2002'
enroll_4['Batch']='Batch_4'
enroll_4['Branch']='MS Ecommerce'
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
enroll_4.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

# %%
enroll_4 = enroll_4.reset_index()

# %%
del enroll_4['index']

# %%
enroll_4=enroll_4.drop("nan",axis=1)

# %%
enroll_4=enroll_4.set_index('NO')

# %%
enroll_5=sheet2[79:84]
enroll_5.loc[:,'year'] = 'Aug 2001 to Feb 2003'
enroll_5['Batch']='Batch_5'
enroll_5['Branch']='MS Ecommerce'
enroll_5.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_5 = enroll_5.reset_index()
del enroll_5['index']
enroll_5=enroll_5.drop("nan",axis=1)
enroll_5=enroll_5.set_index('NO')

# %%
enroll_6=sheet2[87:102]
enroll_6.loc[:,'year'] = 'Aug 1998 to Feb 2000'
enroll_6['Batch']='Batch_1'
enroll_6['Branch']='MS MEDICAL SOFTWARE'
enroll_6.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_6 = enroll_6.reset_index()
del enroll_6['index']
enroll_6=enroll_6.drop("nan",axis=1)
enroll_6=enroll_6.set_index('NO')

# %%
enroll_7=sheet2[103:113]
enroll_7.loc[:,'year'] = 'Feb 1999 to Aug 2000'
enroll_7['Batch']='Batch_2'
enroll_7['Branch']='MS MEDICAL SOFTWARE'
enroll_7.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_7 = enroll_7.reset_index()
del enroll_7['index']
enroll_7=enroll_7.drop("nan",axis=1)
enroll_7=enroll_7.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_8=sheet2[114:124]
enroll_8.loc[:,'year'] = 'Aug 1999 to Feb 2001'
enroll_8['Batch']='Batch_3'
enroll_8['Branch']='MS MEDICAL SOFTWARE'
enroll_8.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_8 = enroll_8.reset_index()
del enroll_8['index']
enroll_8=enroll_8.drop("nan",axis=1)
enroll_8=enroll_8.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_9=sheet2[125:132]
enroll_9.loc[:,'year'] = 'Aug 2000 to Feb 2002'
enroll_9['Batch']='Batch_4'
enroll_9['Branch']='MS MEDICAL SOFTWARE'
enroll_9.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_9 = enroll_9.reset_index()
del enroll_9['index']
enroll_9=enroll_9.drop("nan",axis=1)
enroll_9=enroll_9.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_10=sheet2[133:150]
enroll_10.loc[:,'year'] = 'Aug 2001 to Feb 2003'
enroll_10['Batch']='Batch_5'
enroll_10['Branch']='MS MEDICAL SOFTWARE'
enroll_10.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_10 = enroll_10.reset_index()
del enroll_10['index']
enroll_10=enroll_10.drop("nan",axis=1)
enroll_10=enroll_10.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_11=sheet2[151:166]
enroll_11.loc[:,'year'] = 'Feb 2002 to Aug 2003'
enroll_11['Batch']='Batch_6'
enroll_11['Branch']='MS MEDICAL SOFTWARE'
enroll_11.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_11 = enroll_11.reset_index()
del enroll_11['index']
enroll_11=enroll_11.drop("nan",axis=1)
enroll_11=enroll_11.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_12=sheet2[167:172]
enroll_12.loc[:,'year'] = 'Aug 2002 to Feb 2004'
enroll_12['Batch']='Batch_7'
enroll_12['Branch']='MS MEDICAL SOFTWARE'
enroll_12.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_12 = enroll_12.reset_index()
del enroll_12['index']
enroll_12=enroll_12.drop("nan",axis=1)
enroll_12=enroll_12.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_13=sheet2[173:189]
enroll_13.loc[:,'year'] = 'Feb 2003 to Feb 2005'
enroll_13['Batch']='Batch_8'
enroll_13['Branch']='MS MEDICAL SOFTWARE'
enroll_13.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_13 = enroll_13.reset_index()
del enroll_13['index']
enroll_13=enroll_13.drop("nan",axis=1)
enroll_13=enroll_13.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_14=sheet2[190:206]
enroll_14.loc[:,'year'] = 'Aug 2003 to Aug 2005'
enroll_14['Batch']='Batch_9'
enroll_14['Branch']='MS MEDICAL SOFTWARE'
enroll_14.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_14 = enroll_14.reset_index()
del enroll_14['index']
enroll_14=enroll_14.drop("nan",axis=1)
enroll_14=enroll_14.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_15=sheet2[207:213]
enroll_15.loc[:,'year'] = 'Feb 2004 to Feb 2006'
enroll_15['Batch']='Batch_10'
enroll_15['Branch']='MS MEDICAL SOFTWARE'
enroll_15.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_15 = enroll_15.reset_index()
del enroll_15['index']
enroll_15=enroll_15.drop("nan",axis=1)
enroll_15=enroll_15.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_16=sheet2[214:224]
enroll_16.loc[:,'year'] = 'Aug 2004 to Aug 2006'
enroll_16['Batch']='Batch_11'
enroll_16['Branch']='MS MEDICAL SOFTWARE'
enroll_16.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_16 = enroll_16.reset_index()
del enroll_16['index']
enroll_16=enroll_16.drop("nan",axis=1)
enroll_16=enroll_16.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_17=sheet2[225:237]
enroll_17.loc[:,'year'] = 'Aug 2005 to Aug 2007'
enroll_17['Batch']='Batch_12'
enroll_17['Branch']='MS MEDICAL SOFTWARE'
enroll_17.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_17 = enroll_17.reset_index()
del enroll_17['index']
enroll_17=enroll_17.drop("nan",axis=1)
enroll_17=enroll_17.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_18=sheet2[238:261]
enroll_18.loc[:,'year'] = 'Aug 2006 to Jul 2008'
enroll_18['Batch']='Batch_13'
enroll_18['Branch']='MS MEDICAL SOFTWARE'
enroll_18.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_18 = enroll_18.reset_index()
del enroll_18['index']
enroll_18=enroll_18.drop("nan",axis=1)
enroll_18=enroll_18.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_19=sheet2[262:269]
enroll_19.loc[:,'year'] = 'Jan 2007 to Dec 2008'
enroll_19['Batch']='Batch_14'
enroll_19['Branch']='MS MEDICAL SOFTWARE'
enroll_19.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_19 = enroll_19.reset_index()
del enroll_19['index']
enroll_19=enroll_19.drop("nan",axis=1)
enroll_19=enroll_19.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_20=sheet2[270:288]
enroll_20.loc[:,'year'] = 'Aug 2007 to July 2009'
enroll_20['Batch']='Batch_15'
enroll_20['Branch']='MS MEDICAL SOFTWARE'
enroll_20.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_20 = enroll_20.reset_index()
del enroll_20['index']
enroll_20=enroll_20.drop("nan",axis=1)
enroll_20=enroll_20.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_21=sheet2[289:291]
enroll_21.loc[:,'year'] = 'Jan 2008 to Dec 2009'
enroll_21['Batch']='Batch_16'
enroll_21['Branch']='MS MEDICAL SOFTWARE'
enroll_21.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_21 = enroll_21.reset_index()
del enroll_21['index']
enroll_21=enroll_21.drop("nan",axis=1)
enroll_21=enroll_21.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_22=sheet2[292:317]
enroll_22.loc[:,'year'] = 'Aug 2008 to July 2010'
enroll_22['Batch']='Batch_17'
enroll_22['Branch']='MS MEDICAL SOFTWARE'
enroll_22.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_22 = enroll_22.reset_index()
del enroll_22['index']
enroll_22=enroll_22.drop("nan",axis=1)
enroll_22=enroll_22.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_23=sheet2[318:328]
enroll_23.loc[:,'year'] = 'Jan 2009 to Dec 2010'
enroll_23['Batch']='Batch_18'
enroll_23['Branch']='MS MEDICAL SOFTWARE'
enroll_23.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_23 = enroll_23.reset_index()
del enroll_23['index']
enroll_23=enroll_23.drop("nan",axis=1)
enroll_23=enroll_23.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_24=sheet2[329:355]
enroll_24.loc[:,'year'] = 'Aug 09 to July 2011'
enroll_24['Batch']='Batch_19'
enroll_24['Branch']='MS MEDICAL SOFTWARE'
enroll_24.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_24 = enroll_24.reset_index()
del enroll_24['index']
enroll_24=enroll_24.drop("nan",axis=1)
enroll_24=enroll_24.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_25=sheet2[356:361]
enroll_25.loc[:,'year'] = 'Jan 2010 to Dec 2011'
enroll_25['Batch']='Batch_20'
enroll_25['Branch']='MS MEDICAL SOFTWARE'
enroll_25.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_25 = enroll_25.reset_index()
del enroll_25['index']
enroll_25=enroll_25.drop("nan",axis=1)
enroll_25=enroll_25.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_26=sheet2[362:392]
enroll_26.loc[:,'year'] = 'Aug 10 to July 2012'
enroll_26['Batch']='Batch_21'
enroll_26['Branch']='MS MEDICAL SOFTWARE'
enroll_26.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_26 = enroll_26.reset_index()
del enroll_26['index']
enroll_26=enroll_26.drop("nan",axis=1)
enroll_26=enroll_26.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_27=sheet2[393:415]
enroll_27.loc[:,'year'] = 'Aug 11 to July 2013'
enroll_27['Batch']='Batch_21'
enroll_27['Branch']='MS MEDICAL SOFTWARE'
enroll_27.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_27 = enroll_27.reset_index()
del enroll_27['index']
enroll_27=enroll_27.drop("nan",axis=1)
enroll_27=enroll_27.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_53=sheet2[968:989]
enroll_53.loc[:,'year'] = 'Aug 2002 to Feb 2004'
enroll_53['Batch']='Batch_1'
enroll_53['Branch']='MS EMBEDDED SYSTEMS'
enroll_53.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_53 = enroll_53.reset_index()
del enroll_53['index']
enroll_53=enroll_53.drop("nan",axis=1)
enroll_53=enroll_53.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_54=sheet2[990:1000]
enroll_54.loc[:,'year'] = 'Feb 2003 to Feb 2005'
enroll_54['Batch']='Batch_2'
enroll_54['Branch']='MS EMBEDDED SYSTEMS'
enroll_54.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_54 = enroll_54.reset_index()
del enroll_54['index']
enroll_54=enroll_54.drop("nan",axis=1)
enroll_54=enroll_54.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_55=sheet2[1001:1031]
enroll_55.loc[:,'year'] = 'Aug 2003 to Jul 2005'
enroll_55['Batch']='Batch_3'
enroll_55['Branch']='MS EMBEDDED SYSTEMS'
enroll_55.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_55 = enroll_55.reset_index()
del enroll_55['index']
enroll_55=enroll_55.drop("nan",axis=1)
enroll_55=enroll_55.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_56=sheet2[1032:1040]
enroll_56.loc[:,'year'] = 'Feb 2004 to Jan 2006'
enroll_56['Batch']='Batch_4'
enroll_56['Branch']='MS EMBEDDED SYSTEMS'
enroll_56.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_56 = enroll_56.reset_index()
del enroll_56['index']
enroll_56=enroll_56.drop("nan",axis=1)
enroll_56=enroll_56.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_57=sheet2[1041:1061]
enroll_57.loc[:,'year'] = 'Aug 2004 to Jul 2006'
enroll_57['Batch']='Batch_5'
enroll_57['Branch']='MS EMBEDDED SYSTEMS'
enroll_57.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_57 = enroll_57.reset_index()
del enroll_57['index']
enroll_57=enroll_57.drop("nan",axis=1)
enroll_57=enroll_57.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_58=sheet2[1062:1073]
enroll_58.loc[:,'year'] = 'Feb 2005 to Jan  2007'
enroll_58['Batch']='Batch_6'
enroll_58['Branch']='MS EMBEDDED SYSTEMS'
enroll_58.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_58 = enroll_58.reset_index()
del enroll_58['index']
enroll_58=enroll_58.drop("nan",axis=1)
enroll_58=enroll_58.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_59=sheet2[1074:1113]
enroll_59.loc[:,'year'] = 'Aug 2005 to Jul  2007'
enroll_59['Batch']='Batch_7'
enroll_59['Branch']='MS EMBEDDED SYSTEMS'
enroll_59.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_59 = enroll_59.reset_index()
del enroll_59['index']
enroll_59=enroll_59.drop("nan",axis=1)
enroll_59=enroll_59.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_60=sheet2[1114:1136]
enroll_60.loc[:,'year'] = 'Jan 2006 to Dec 2007'
enroll_60['Batch']='Batch_8'
enroll_60['Branch']='MS EMBEDDED SYSTEMS'
enroll_60.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_60 = enroll_60.reset_index()
del enroll_60['index']
enroll_60=enroll_60.drop("nan",axis=1)
enroll_60=enroll_60.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_61=sheet2[1137:1187]
enroll_61.loc[:,'year'] = 'Aug 2006 July 2008'
enroll_61['Batch']='Batch_9'
enroll_61['Branch']='MS EMBEDDED SYSTEMS'
enroll_61.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_61 = enroll_61.reset_index()
del enroll_61['index']
enroll_61=enroll_61.drop("nan",axis=1)
enroll_61=enroll_61.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_62=sheet2[1188:1217]
enroll_62.loc[:,'year'] = 'Jan 2007 to Dec 2008'
enroll_62['Batch']='Batch_10'
enroll_62['Branch']='MS EMBEDDED SYSTEMS'
enroll_62.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_62 = enroll_62.reset_index()
del enroll_62['index']
enroll_62=enroll_62.drop("nan",axis=1)
enroll_62=enroll_62.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_63=sheet2[1218:1309]
enroll_63.loc[:,'year'] = 'Aug 2007 to Jul 2009'
enroll_63['Batch']='Batch_11'
enroll_63['Branch']='MS EMBEDDED SYSTEMS'
enroll_63.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_63 = enroll_63.reset_index()
del enroll_63['index']
enroll_63=enroll_63.drop("nan",axis=1)
enroll_63=enroll_63.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_64=sheet2[1310:1330]
enroll_64.loc[:,'year'] = 'Jan 2008 to Dec 2009'
enroll_64['Batch']='Batch_12'
enroll_64['Branch']='MS EMBEDDED SYSTEMS'
enroll_64.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_64 = enroll_64.reset_index()
del enroll_64['index']
enroll_64=enroll_64.drop("nan",axis=1)
enroll_64=enroll_64.set_index('NO')

enroll_65=sheet2[1331:1425]
enroll_65.loc[:,'year'] = 'Aug 2008 to July2010'
enroll_65['Batch']='Batch_13'
enroll_65['Branch']='MS EMBEDDED SYSTEMS'
enroll_65.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_65 = enroll_65.reset_index()
del enroll_65['index']
enroll_65=enroll_65.drop("nan",axis=1)
enroll_65=enroll_65.set_index('NO')

enroll_66=sheet2[1428:1435]
enroll_66.loc[:,'year'] = 'Jan 2009 to Dec 2010'
enroll_66['Batch']='Batch_14'
enroll_66['Branch']='MS EMBEDDED SYSTEMS'
enroll_66.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_66 = enroll_66.reset_index()
del enroll_66['index']
enroll_66=enroll_66.drop("nan",axis=1)
enroll_66=enroll_66.set_index('NO')

enroll_67=sheet2[1436:1570]
enroll_67.loc[:,'year'] = 'Aug 2009 to July 2011'
enroll_67['Batch']='Batch_15'
enroll_67['Branch']='MS EMBEDDED SYSTEMS'
enroll_67.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_67 = enroll_67.reset_index()
del enroll_67['index']
enroll_67=enroll_67.drop("nan",axis=1)
enroll_67=enroll_67.set_index('NO')

enroll_68=sheet2[1571:1623]
enroll_68.loc[:,'year'] = 'Jan 2010 to Dec 2011'
enroll_68['Batch']='Batch_16'
enroll_68['Branch']='MS EMBEDDED SYSTEMS'
enroll_68.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_68 = enroll_68.reset_index()
del enroll_68['index']
enroll_68=enroll_68.drop("nan",axis=1)
enroll_68=enroll_68.set_index('NO')

enroll_69=sheet2[1626:1706]
enroll_69.loc[:,'year'] = 'Aug 2010 to Jul 2012'
enroll_69['Batch']='Batch_17'
enroll_69['Branch']='MS EMBEDDED SYSTEMS'
enroll_69.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_69 = enroll_69.reset_index()
del enroll_69['index']
enroll_69=enroll_69.drop("nan",axis=1)
enroll_69=enroll_69.set_index('NO')

enroll_70=sheet2[1709:1759]
enroll_70.loc[:,'year'] = 'Jan 2011 to Dec 2012'
enroll_70['Batch']='Batch_18'
enroll_70['Branch']='MS EMBEDDED SYSTEMS'
enroll_70.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_70 = enroll_70.reset_index()
del enroll_70['index']
enroll_70=enroll_70.drop("nan",axis=1)
enroll_70=enroll_70.set_index('NO')

enroll_71=sheet2[1762:1842]
enroll_71.loc[:,'year'] = 'Aug 2011 to Jul 2013'
enroll_71['Batch']='Batch_19'
enroll_71['Branch']='MS EMBEDDED SYSTEMS'
enroll_71.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_71 = enroll_71.reset_index()
del enroll_71['index']
enroll_71=enroll_71.drop("nan",axis=1)
enroll_71=enroll_71.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_72=sheet2[1861:1891]
enroll_72.loc[:,'year'] = 'Aug 2010 to Jul 2012'
enroll_72['Batch']='Batch_1'
enroll_72['Branch']=' MS Embedded & Wireless Technology '
enroll_72.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_72 = enroll_72.reset_index()
del enroll_72['index']
enroll_72=enroll_72.drop("nan",axis=1)
enroll_72=enroll_72.set_index('NO')

enroll_73=sheet2[1894:1909]
enroll_73.loc[:,'year'] = 'JAN 2011 to DEC 2012'
enroll_73['Batch']='Batch_2'
enroll_73['Branch']=' MS Embedded & Wireless Technology '
enroll_73.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_73 = enroll_73.reset_index()
del enroll_73['index']
enroll_73=enroll_73.drop("nan",axis=1)
enroll_73=enroll_73.set_index('NO')

enroll_74=sheet2[1912:1942]
enroll_74.loc[:,'year'] = 'Aug 2011 to Jul 2013'
enroll_74['Batch']='Batch_3'
enroll_74['Branch']=' MS Embedded & Wireless Technology '
enroll_74.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_74 = enroll_74.reset_index()
del enroll_74['index']
enroll_74=enroll_74.drop("nan",axis=1)
enroll_74=enroll_74.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_85=sheet2[2186:2223]
enroll_85.loc[:,'year'] = 'Jan 2012 to Dec  2013'
enroll_85['Batch']='Batch_1'
enroll_85['Branch']=' MSc Tech Embedded Systems '
enroll_85.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_85 = enroll_85.reset_index()
del enroll_85['index']
enroll_85=enroll_85.drop("nan",axis=1)
enroll_85=enroll_85.set_index('NO')

enroll_86=sheet2[2226:2237]
enroll_86.loc[:,'year'] = 'Jan 2012 to Dec  2013'
enroll_86['Batch']='Batch_1'
enroll_86['Branch']=' MSc Tech VLSI DESIGN  '
enroll_86.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_86 = enroll_86.reset_index()
del enroll_86['index']
enroll_86=enroll_86.drop("nan",axis=1)
enroll_86=enroll_86.set_index('NO')

enroll_87=sheet2[2257:2262]
enroll_87.loc[:,'year'] = 'Aug 2000 to Jul 2001'
enroll_87['Batch']='Batch_1'
enroll_87['Branch']='PG DIPLOMA IN E-COMMERCE'
enroll_87.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_87 = enroll_87.reset_index()
del enroll_87['index']
enroll_87=enroll_87.drop("nan",axis=1)
enroll_87=enroll_87.set_index('NO')

enroll_88=sheet2[2264:2270]
enroll_88.loc[:,'year'] = 'Aug 2001 to Jul 2004'
enroll_88['Batch']='Batch_1'
enroll_88['Branch']='BACHELOR OF COMPUTER APPLICATION'
enroll_88.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_88 = enroll_88.reset_index()
del enroll_88['index']
enroll_88=enroll_88.drop("nan",axis=1)
enroll_88=enroll_88.set_index('NO')

enroll_89=sheet2[2271:2276]
enroll_89.loc[:,'year'] = 'Aug 2002 to Jul 2005'
enroll_89['Batch']='Batch_2'
enroll_89['Branch']='BACHELOR OF COMPUTER APPLICATION'
enroll_89.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_89 = enroll_89.reset_index()
del enroll_89['index']
enroll_89=enroll_89.drop("nan",axis=1)
enroll_89=enroll_89.set_index('NO')


enroll_90=sheet2[2277:2285]
enroll_90.loc[:,'year'] = 'Aug 2003 to Jul 2006'
enroll_90['Batch']='Batch_3'
enroll_90['Branch']='BACHELOR OF COMPUTER APPLICATION'
enroll_90.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_90 = enroll_90.reset_index()
del enroll_90['index']
enroll_90=enroll_90.drop("nan",axis=1)
enroll_90=enroll_90.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_91=sheet2[2288:2308]
enroll_91.loc[:,'year'] = 'Aug 2005 to July 2007'
enroll_91['Batch']='Batch_1'
enroll_91['Branch']='MSc DIGITAL DESIGN & EMBEDDED SYSTEMS'
enroll_91.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_91 = enroll_91.reset_index()
del enroll_91['index']
enroll_91=enroll_91.drop("nan",axis=1)
enroll_91=enroll_91.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_92=sheet2[2309:2327]
enroll_92.loc[:,'year'] = 'Aug 2006 to July 2008'
enroll_92['Batch']='Batch_2'
enroll_92['Branch']='MSc DIGITAL DESIGN & EMBEDDED SYSTEMS'
enroll_92.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_92 = enroll_92.reset_index()
del enroll_92['index']
enroll_92=enroll_92.drop("nan",axis=1)
enroll_92=enroll_92.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
list1=[7,8,12,13,16,17]
for i in range(0,6):
    enroll_92=enroll_92.drop(list1[i],axis=0)

# %%
enroll_92.index=range(1,13)

# %%
enroll_93=sheet2[2328:2340]
enroll_93.loc[:,'year'] = 'Aug 2007 to July 2009'
enroll_93['Batch']='Batch_3'
enroll_93['Branch']='MSc DIGITAL DESIGN & EMBEDDED SYSTEMS'
enroll_93.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_93 = enroll_93.reset_index()
del enroll_93['index']
enroll_93=enroll_93.drop("nan",axis=1)
enroll_93=enroll_93.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_94=sheet2[2341:2355]
enroll_94.loc[:,'year'] = 'Aug 2008 to July 2010'
enroll_94['Batch']='Batch_4'
enroll_94['Branch']='MSc DIGITAL DESIGN & EMBEDDED SYSTEMS'
enroll_94.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_94 = enroll_94.reset_index()
del enroll_94['index']
enroll_94=enroll_94.drop("nan",axis=1)
enroll_94=enroll_94.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_95=sheet2[2356:2363]
enroll_95.loc[:,'year'] = 'Aug 2009 to July 2011'
enroll_95['Batch']='Batch_5'
enroll_95['Branch']='MSc DIGITAL DESIGN & EMBEDDED SYSTEMS'
enroll_95.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_95 = enroll_95.reset_index()
del enroll_95['index']
enroll_95=enroll_95.drop("nan",axis=1)
enroll_95=enroll_95.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_96=sheet2[2366:2374]
enroll_96.loc[:,'year'] = 'Aug 2010 to Jul 2012'
enroll_96['Batch']='Batch_6'
enroll_96['Branch']='MSc DIGITAL DESIGN & EMBEDDED SYSTEMS'
enroll_96.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_96 = enroll_96.reset_index()
del enroll_96['index']
enroll_96=enroll_96.drop("nan",axis=1)
enroll_96=enroll_96.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_97=sheet2[2377:2382]
enroll_97.loc[:,'year'] = 'Aug 2011 to Jul 2013'
enroll_97['Batch']='Batch_7'
enroll_97['Branch']='MSc DIGITAL DESIGN & EMBEDDED SYSTEMS'
enroll_97.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_97 = enroll_97.reset_index()
del enroll_97['index']
enroll_97=enroll_97.drop("nan",axis=1)
enroll_97=enroll_97.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_98=sheet2[2441:2445]
enroll_98.loc[:,'year'] = 'Aug 2005 to Jul 2007'
enroll_98['Batch']='Batch_1'
enroll_98['Branch']='MSc INFORMATION SCIENCE'
enroll_98.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_98 = enroll_98.reset_index()
del enroll_98['index']
enroll_98=enroll_98.drop("nan",axis=1)
enroll_98=enroll_98.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_99=sheet2[2446:2453]
enroll_99.loc[:,'year'] = 'Aug 2006 to Jul 2008'
enroll_99['Batch']='Batch_2'
enroll_99['Branch']='MSc INFORMATION SCIENCE'
enroll_99.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_99 = enroll_99.reset_index()
del enroll_99['index']
enroll_99=enroll_99.drop("nan",axis=1)
enroll_99=enroll_99.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_100=sheet2[2454:2460]
enroll_100.loc[:,'year'] = 'Aug 2007 to Jul 2009'
enroll_100['Batch']='Batch_3'
enroll_100['Branch']='MSc INFORMATION SCIENCE'
enroll_100.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_100 = enroll_100.reset_index()
del enroll_100['index']
enroll_100=enroll_100.drop("nan",axis=1)
enroll_100=enroll_100.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_101=sheet2[2461:2470]
enroll_101.loc[:,'year'] = 'Aug 2008 to Jul 2010'
enroll_101['Batch']='Batch_4'
enroll_101['Branch']='MSc INFORMATION SCIENCE'
enroll_101.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_101 = enroll_101.reset_index()
del enroll_101['index']
enroll_101=enroll_101.drop("nan",axis=1)
enroll_101=enroll_101.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_102=sheet2[2471:2479]
enroll_102.loc[:,'year'] = 'Aug 2009 to Jul 2011'
enroll_102['Batch']='Batch_5'
enroll_102['Branch']='MSc INFORMATION SCIENCE'
enroll_102.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_102 = enroll_102.reset_index()
del enroll_102['index']
enroll_102=enroll_102.drop("nan",axis=1)
enroll_102=enroll_102.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_103=sheet2[2481:2501]
enroll_103.loc[:,'year'] = 'Aug 2010 to Jul 2012'
enroll_103['Batch']='Batch_6'
enroll_103['Branch']='MSc INFORMATION SCIENCE'
enroll_103.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_103 = enroll_103.reset_index()
del enroll_103['index']
enroll_103=enroll_103.drop("nan",axis=1)
enroll_103=enroll_103.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_104=sheet2[2502:2519]
enroll_104.loc[:,'year'] = 'Aug 2011 to Jul 2013'
enroll_104['Batch']='Batch_7'
enroll_104['Branch']='MSc INFORMATION SCIENCE'
enroll_104.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_104 = enroll_104.reset_index()
del enroll_104['index']
enroll_104=enroll_104.drop("nan",axis=1)
enroll_104=enroll_104.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_105=sheet2[2534:2539]
enroll_105.loc[:,'year'] = 'Aug 2007 to Jul 2009'
enroll_105['Batch']='Batch_1'
enroll_105['Branch']='MSc WEB COMMERCE'
enroll_105.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']
enroll_105 = enroll_105.reset_index()
del enroll_105['index']
enroll_105=enroll_105.drop("nan",axis=1)
enroll_105=enroll_105.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_28=sheet2[447:458]

enroll_28.loc[:,'year'] = 'Aug 1999 to Feb 2001'

enroll_28['Batch']='Batch_1'

enroll_28['Branch']='MS VLSI-CAD'

enroll_28.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_28 = enroll_28.reset_index()

del enroll_28['index']

enroll_28=enroll_28.drop("nan",axis=1)

enroll_28=enroll_28.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_29=sheet2[459:466]

enroll_29.loc[:,'year'] = 'Feb 2000 to Aug 2001'

enroll_29['Batch']='Batch_2'

enroll_29['Branch']='MS VLSI-CAD'

enroll_29.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_29 = enroll_29.reset_index()

del enroll_29['index']

enroll_29=enroll_29.drop("nan",axis=1)

enroll_29=enroll_29.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_30=sheet2[467:480]

enroll_30.loc[:,'year'] = 'Aug 2000 to Feb 2002'

enroll_30['Batch']='Batch_3'

enroll_30['Branch']='MS VLSI-CAD'

enroll_30.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_30 = enroll_30.reset_index()

del enroll_30['index']

enroll_30=enroll_30.drop("nan",axis=1)

enroll_30=enroll_30.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_31=sheet2[481:487]

enroll_31.loc[:,'year'] = 'Feb 2001 to Aug 2002'

enroll_31['Batch']='Batch_4'

enroll_31['Branch']='MS VLSI-CAD'

enroll_31.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_31 = enroll_31.reset_index()

del enroll_31['index']

enroll_31=enroll_31.drop("nan",axis=1)

enroll_31=enroll_31.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_32=sheet2[488:522]

enroll_32.loc[:,'year'] = 'Aug 2001 to Feb 2003'

enroll_32['Batch']='Batch_5'

enroll_32['Branch']='MS VLSI-CAD'

enroll_32.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_32 = enroll_32.reset_index()

del enroll_32['index']

enroll_32=enroll_32.drop("nan",axis=1)

enroll_32=enroll_32.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_33=sheet2[523:547]

enroll_33.loc[:,'year'] = 'Feb 2002 to Aug 2003'

enroll_33['Batch']='Batch_6'

enroll_33['Branch']='MS VLSI-CAD'

enroll_33.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_33 = enroll_33.reset_index()

del enroll_33['index']

enroll_33=enroll_33.drop("nan",axis=1)

enroll_33=enroll_33.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_34=sheet2[548:579]

enroll_34.loc[:,'year'] = 'Aug 2002 to Feb 2004'

enroll_34['Batch']='Batch_7'

enroll_34['Branch']='MS VLSI-CAD'

enroll_34.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_34 = enroll_34.reset_index()

del enroll_34['index']

enroll_34=enroll_34.drop("nan",axis=1)

enroll_34=enroll_34.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_35=sheet2[580:592]

enroll_35.loc[:,'year'] = 'Feb  2003 to Feb 2005'

enroll_35['Batch']='Batch_8'

enroll_35['Branch']='MS VLSI-CAD'

enroll_35.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_35 = enroll_35.reset_index()

del enroll_35['index']

enroll_35=enroll_35.drop("nan",axis=1)

enroll_35=enroll_35.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_36=sheet2[593:612]

enroll_36.loc[:,'year'] = 'Aug 2003 to Aug 2005'

enroll_36['Batch']='Batch_9'

enroll_36['Branch']='MS VLSI-CAD'

enroll_36.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_36 = enroll_36.reset_index()

del enroll_36['index']

enroll_36=enroll_36.drop("nan",axis=1)

enroll_36=enroll_36.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_37=sheet2[613:615]

enroll_37.loc[:,'year'] = ''

enroll_37['Batch']='Batch_10'

enroll_37['Branch']='MS VLSI-CAD'

enroll_37.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_37 = enroll_37.reset_index()

del enroll_37['index']

enroll_37=enroll_37.drop("nan",axis=1)

enroll_37=enroll_37.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_38=sheet2[616:641]

enroll_38.loc[:,'year'] = 'Aug 2004 to Aug 2006'

enroll_38['Batch']='Batch_11'

enroll_38['Branch']='MS VLSI-CAD'

enroll_38.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_38 = enroll_38.reset_index()

del enroll_38['index']

enroll_38=enroll_38.drop("nan",axis=1)

enroll_38=enroll_38.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_39=sheet2[642:648]

enroll_39.loc[:,'year'] = 'Aug 2005 Jul 2007'

enroll_39['Batch']='Batch_1'

enroll_39['Branch']='MSc INFORMATION SCIENCE'

enroll_39.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_39 = enroll_39.reset_index()

del enroll_39['index']

enroll_39=enroll_39.drop("nan",axis=1)

enroll_39=enroll_39.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_40=sheet2[649:676]

enroll_40.loc[:,'year'] = 'Aug 2005 to Aug 2007'

enroll_40['Batch']='Batch_13'

enroll_40['Branch']='MS VLSI-CAD'

enroll_40.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_40 = enroll_40.reset_index()

del enroll_40['index']

enroll_40=enroll_40.drop("nan",axis=1)

enroll_40=enroll_40.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_41=sheet2[677:684]

enroll_41.loc[:,'year'] = 'Jan 2006 to Dec 2007'

enroll_41['Batch']='Batch_14'

enroll_41['Branch']='MS VLSI-CAD'

enroll_41.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_41 = enroll_41.reset_index()

del enroll_41['index']

enroll_41=enroll_41.drop("nan",axis=1)

enroll_41=enroll_41.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_42=sheet2[685:716]

enroll_42.loc[:,'year'] = 'Aug 2006 to July 2008'

enroll_42['Batch']='Batch_15'

enroll_42['Branch']='MS VLSI-CAD'

enroll_42.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_42 = enroll_42.reset_index()

del enroll_42['index']

enroll_42=enroll_42.drop("nan",axis=1)

enroll_42=enroll_42.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_43=sheet2[717:723]

enroll_43.loc[:,'year'] = 'Jan 2007 Dec 2008'

enroll_43['Batch']='Batch_16'

enroll_43['Branch']='MS VLSI-CAD'

enroll_43.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_43 = enroll_43.reset_index()

del enroll_43['index']

enroll_43=enroll_43.drop("nan",axis=1)

enroll_43=enroll_43.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_44=sheet2[724:764]

enroll_44.loc[:,'year'] = 'Aug 2007Jul 2009'

enroll_44['Batch']='Batch_17'

enroll_44['Branch']='MS VLSI-CAD'

enroll_44.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_44 = enroll_44.reset_index()

del enroll_44['index']

enroll_44=enroll_44.drop("nan",axis=1)

enroll_44=enroll_44.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_45=sheet2[765:772]

enroll_45.loc[:,'year'] = 'Jan 2008 - Dec 2009'

enroll_45['Batch']='Batch_18'

enroll_45['Branch']='MS VLSI-CAD'

enroll_45.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_45 = enroll_45.reset_index()

del enroll_45['index']

enroll_45=enroll_45.drop("nan",axis=1)

enroll_45=enroll_45.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_46=sheet2[773:788]

enroll_46.loc[:,'year'] = 'Aug 2008 - July 2010'

enroll_46['Batch']='Batch_19'

enroll_46['Branch']='MS VLSI-CAD'

enroll_46.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_46 = enroll_46.reset_index()

del enroll_46['index']

enroll_46=enroll_46.drop("nan",axis=1)

enroll_46=enroll_46.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_47=sheet2[789:796]

enroll_47.loc[:,'year'] = 'Jan 2009 to Dec 2010'

enroll_47['Batch']='Batch_20'

enroll_47['Branch']='MS VLSI-CAD'

enroll_47.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_47 = enroll_47.reset_index()

del enroll_47['index']

enroll_47=enroll_47.drop("nan",axis=1)

enroll_47=enroll_47.set_index('NO')
enroll_47=enroll_47.drop("Sl. No.",axis=0)
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_48=sheet2[797:837]

enroll_48.loc[:,'year'] = 'Aug 2009 - July 2011'

enroll_48['Batch']='Batch_21'

enroll_48['Branch']='MS VLSI-CAD'

enroll_48.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_48 = enroll_48.reset_index()

del enroll_48['index']

enroll_48=enroll_48.drop("nan",axis=1)

enroll_48=enroll_48.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_49=sheet2[838:844]

enroll_49.loc[:,'year'] = 'Jan 2010 to Dec 2011'

enroll_49['Batch']='Batch_22'

enroll_49['Branch']='MS VLSI-CAD'

enroll_49.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_49 = enroll_49.reset_index()

del enroll_49['index']

enroll_49=enroll_49.drop("nan",axis=1)

enroll_49=enroll_49.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_50=sheet2[847:887]

enroll_50.loc[:,'year'] = ' Aug 2010 - July 2012'

enroll_50['Batch']='Batch_23'

enroll_50['Branch']='MS VLSI-CAD'

enroll_50.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_50 = enroll_50.reset_index()

del enroll_50['index']

enroll_50=enroll_50.drop("nan",axis=1)

enroll_50=enroll_50.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_51=sheet2[891:893]

enroll_51.loc[:,'year'] = 'Jan 2011 to Dec 2012'

enroll_51['Batch']='Batch_24'

enroll_51['Branch']='MS VLSI-CAD'

enroll_51.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_51 = enroll_51.reset_index()

del enroll_51['index']

enroll_51=enroll_51.drop("nan",axis=1)

enroll_51=enroll_51.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_52=sheet2[896:936]

enroll_52.loc[:,'year'] = 'Aug 2011 - July 2013'

enroll_52['Batch']='Batch_25'

enroll_52['Branch']='MS VLSI-CAD'

enroll_52.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_52 = enroll_52.reset_index()

del enroll_52['index']

enroll_52=enroll_52.drop("nan",axis=1)

enroll_52=enroll_52.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_75=sheet2[1949:1957]

enroll_75.loc[:,'year'] = 'Aug 2009 to July 2011'

enroll_75['Batch']='Batch_1'

enroll_75['Branch']='MS VLSI-AXIOM'

enroll_75.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_75 = enroll_75.reset_index()

del enroll_75['index']

enroll_75=enroll_75.drop("nan",axis=1)

enroll_75=enroll_75.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_76=sheet2[1960:1975]

enroll_76.loc[:,'year'] = 'Aug 2010 to July 2012'

enroll_76['Batch']='Batch_2'

enroll_76['Branch']='MS VLSI-AXIOM'

enroll_76.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_76 = enroll_76.reset_index()

del enroll_76['index']

enroll_76=enroll_76.drop("nan",axis=1)

enroll_76=enroll_76.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_77=sheet2[1978:1989]

enroll_77.loc[:,'year'] = 'Aug 2011 to July 2013'

enroll_77['Batch']='Batch_3'

enroll_77['Branch']='MS VLSI-AXIOM'

enroll_77.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_77 = enroll_77.reset_index()

del enroll_77['index']

enroll_77=enroll_77.drop("nan",axis=1)

enroll_77=enroll_77.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_78=sheet2[2032:2041]

enroll_78.loc[:,'year'] = 'Aug 2009July 2011'

enroll_78['Batch']='Batch_1'

enroll_78['Branch']='MS DUAL DEGREE'

enroll_78.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_78 = enroll_78.reset_index()

del enroll_78['index']

enroll_78=enroll_78.drop("nan",axis=1)

enroll_78=enroll_78.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_79=sheet2[2044:2064]

enroll_79.loc[:,'year'] = 'Aug 2010 to July 2012'

enroll_79['Batch']='Batch_2'

enroll_79['Branch']='MS DUAL DEGREE'

enroll_79.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_79 = enroll_79.reset_index()

del enroll_79['index']

enroll_79=enroll_79.drop("nan",axis=1)

enroll_79=enroll_79.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_80=sheet2[2067:2086]

enroll_80.loc[:,'year'] = 'Aug 2011 to July 2013'

enroll_80['Batch']='Batch_3'

enroll_80['Branch']='MS DUAL DEGREE'

enroll_80.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_80 = enroll_80.reset_index()

del enroll_80['index']

enroll_80=enroll_80.drop("nan",axis=1)

enroll_80=enroll_80.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_81=sheet2[2108:2123]

enroll_81.loc[:,'year'] = 'Aug 2010 to Jul 2012'

enroll_81['Batch']='Batch_4'

enroll_81['Branch']='MS IT'

enroll_81.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_81 = enroll_81.reset_index()

del enroll_81['index']

enroll_81=enroll_81.drop("nan",axis=1)

enroll_81=enroll_81.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_82=sheet2[2127:2143]

enroll_82.loc[:,'year'] = 'August2011'

enroll_82['Batch']='Batch_5'

enroll_82['Branch']='MS IT'

enroll_82.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_82 = enroll_82.reset_index()

del enroll_82['index']

enroll_82=enroll_82.drop("nan",axis=1)

enroll_82=enroll_82.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_83=sheet2[2146:2170]

enroll_83.loc[:,'year'] = 'Aug 2011 to Jul 2013'

enroll_83['Batch']='Batch_1'

enroll_83['Branch']='MS Computing Technologies & Virtualization '

enroll_83.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_83 = enroll_83.reset_index()

del enroll_83['index']

enroll_83=enroll_83.drop("nan",axis=1)

enroll_83=enroll_83.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_84=sheet2[2173:2182]

enroll_84.loc[:,'year'] = 'Aug 2011 to Jul 2013'

enroll_84['Batch']='Batch_1'

enroll_84['Branch']='MS DUAL - LU & ENU '

enroll_84.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_84 = enroll_84.reset_index()

del enroll_84['index']

enroll_84=enroll_84.drop("nan",axis=1)

enroll_84=enroll_84.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
enroll_39=sheet2[642:648]

enroll_39.loc[:,'year'] = 'Aug 2005 Jul 2007'

enroll_39['Batch']='Batch_1'

enroll_39['Branch']='MSc INFORMATION SCIENCE'

enroll_39.columns = ['NO','ROLL NO','NAME','Gender','State','nan','Year','Batch','Branch']

enroll_39 = enroll_39.reset_index()

del enroll_39['index']

enroll_39=enroll_39.drop("nan",axis=1)

enroll_39=enroll_39.set_index('NO')
# Out:
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ravali/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ravali/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### convert data frames to csv

# %%
def convert_csv(start,end,file_name):
    for i in range(start,end):
        values=(eval(file_name.format(i)))
        values.to_csv(file_name.format(i))

# %%
convert_csv(1,14,'df{}')

# %%
convert_csv(1,105,'enroll_{}')

# %% [markdown]
# ### anonymize roll no. and name

# %%
def hash_func(data):
    enroll_select=data.ix[:,0:2]
    s=[]
    for i,val in enroll_select.iterrows() :
        roll=str(val['ROLL NO'])
        name=str(val['NAME'])
        hash_roll = hashlib.md5(roll.encode())
        hash_name = hashlib.md5(name.encode())
        hash_roll = hash_roll.hexdigest()
        hash_name = hash_name.hexdigest()
        s.append([hash_roll,hash_name])
        columns = ['ROLL NO', 'NAME']
        hashed_df=pd.DataFrame(s,columns=columns)
    data_del=data.drop(['ROLL NO','NAME'],axis=1)
    data_del = data_del.reset_index(drop = True)
    hashed_df=pd.concat([hashed_df,data_del],axis=1,join_axes=[hashed_df.index],join='inner')
    hashed_df=hashed_df.set_index([data.index])
    
    return hashed_df

# %%
    for g in range(1,106):
        file='enroll_{}'.format(g)
        file=eval(file)
        hashed_file=hash_func(file)
        hashed_file= exec ("hashed_enroll_%s= hashed_file" % (g))

# %%
hashed_enroll_1
# Out:
#                              ROLL NO                              NAME Gender  \
# NO
# 1   08b271c58ca7697d7b7ee45ccfbec5c3  2fc4a1e656dcbdea9d493869df90ae19      M
# 2   0b5cad8c75e1119aa8426240471fd6e2  7e4ddcdb12454a4d53a587aa07bd3fa8      M
# 3   3e3d29e7afb6ca9aee80fbf9162ac6b0  5c03c43fcb94992c565f75bb8bf3cd44      F
# 4   5a88c4af3b0a7a5f0b64cb53a6c045db  eb2aa43e4f47da9d74d460a3f1c779ab      F
# 5   b6689eb301fdc5b932a3fe16c062bf9e  e7f4f69624785acc64f7ca275662d38d      M
# 6   f287bd9353f18f5827b87aa55ae83a2c  89904767affef69f6a1fc1913d466ef9      M
# 7   c9462766ad335d78f70d2ee47a7fe6ac  08fd6b68b81abe827d48bedf4d29180b      F
# 8   c17f353406bc47118ac624f2928c71a2  5e445f6ab4e92feccef8ba96b494bc33      M
# 9   7dd4fceb5a8a36e5547a397a7f46e516  a675b8c088d6bb2a17cb40a9be3e8d03      M
# 10  fd20c435f1db392fd031c379695b4e00  3c8e967d75e4c2c2a79a3ee672d3c4dd      M
# 11  ac151ef912850b4902b6af084fa1901b  f21e4a0816225c761d0067c8d377a3f2      F
# 12  6b8527c7e25ade9b455f96574aff5eca  065b4121ecca00af8b07fcad94aa910d      M
# 13  2f882f5e65d9b26bdfc760e7ffc71efe  f907b93162663fe49603951c30314b32      M
# 14  7295d75f8b54646dbcfcb8ffa666b91b  ce96bbbdf85c018c7384149320ef38f0      M
# 15  fcfeee0211939275f3c4d04273f98e8a  c503543f7966a60d2636668b9d3ad885      F
# 16  9df76f07455c3be90f0de980633cc6ea  5d5f6af17e27d04a269114c0d2b0f047      F
# 17  d5557fb72946903fc87234e19c00d601  6d4cd39b2c4cb9714f7b5483b5163873      M
# 18  f46f5562b74ef3de8e53bc793763af79  3044b8f52e80d5a52c779aac412faedf      M
# 19  16149e91685100e17e40d3a8ae0d9ef6  fea04db28c34914a1823757390c9a7b1      M
# 20  4ab0d3114cb89a671fbbe04702f668e9  b69621bd0a04e1558bc402ea74d19103      M
# 21  86e6c33e556897e14d10e530787db98a  f58cc77029df64ecb6842529596ea952      M
# 22  8aa8dfe2664c9182dd844dc7baf9a590  e5abdfb9d6256224ee250c5391110cc6      M
# 23  2f5a73e25249791aa15216f02425af2b  a7deaa42325689f43dfed12775f515f7      M
# 24  fbb178c30a4864b50955a3ac64d9577a  927f4f71ac2d75cd20d9e00cd72ba20a      M
# 25  d094d7a48c450dd2a603f45e76eef633  b06f853039eee7f6bc5beaef7993b8f1      F
# 26  533fe98fb007d9446c480fba3bac2cc0  c377f86b89fcc33593e3aeaad0706203      F
# 27  90470b02d2c49713e89d00642d64664e  f8ad4b2d72f94413fbfcbce6b3a77ea8      F
# 28  8b526eee551ac6d2f1cd98a779feb390  0b40749fe3bab7b917f36838468021f4      M
# 29  ce46389b113527185d41a6efde0f1afa  702ceaaf9a1d2821e237e51ee9cc4ac7      M
# 30  efdd28dc81993dbde6b4080ce41758ee  e493a061e01bae86857a6a790800caf8      M
# 31  96afae439bfb6a91cf960406b6683b3a  b1c614ce5a939b8a6337b8194b12fa88      M
#
#    State                  Year    Batch        Branch
# NO
# 1    KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 2    KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 3    KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 4    DEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 5    KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 6    KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 7    KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 8    KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 9    KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 10   KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 11    AP  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 12   KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 13   KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 14   TAM  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 15   KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 16   KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 17   DEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 18    AP  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 19   KAR  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 20   KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 21   KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 22   KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 23   KEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 24   DEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 25   DEL  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 26    AP  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 27   KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 28    WB  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 29   KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 30   KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 31   KAN  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce

# %% [markdown]
# ## Visualization

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Medical Software']
    exec ("file_%s= f" % (i))

# %%
medical=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
medical
# Out:
#            Branches Class Strength_1 # of placed students_1 Class Strength_8  \
# 0  Medical Software                0                      0                8
# 0  Medical Software                0                      0               14
# 0  Medical Software                0                      0               12
# 0  Medical Software                0                      0               22
# 0  Medical Software                0                      0               23
# 0  Medical Software                5                      4               30
# 0  Medical Software               10                      6               26
# 0  Medical Software                2                      2               24
# 0  Medical Software                7                      7               18
# 0  Medical Software                0                      0               24
# 0  Medical Software                0                      0               11
# 0  Medical Software                6                      5               10
# 0  Medical Software               15                      6               16
#
#   # of placed students_8 Class Strength # of placed students  \
# 0                      6              8                    6
# 0                     12             14                   12
# 0                     12             12                   12
# 0                     20             22                   20
# 0                     15             23                   15
# 0                     26             35                   30
# 0                     19             36                   25
# 0                     15             26                   17
# 0                     15             25                   22
# 0                     19             24                   19
# 0                     11             11                   11
# 0                      7             16                   12
# 0                      7             31                   13
#
#   Total placement %  year_intake
# 0                75         2015
# 0           85.7143         2014
# 0               100         2013
# 0           90.9091         2012
# 0           65.2174         2011
# 0           85.7143         2010
# 0           69.4444         2009
# 0           65.3846         2008
# 0                88         2007
# 0           79.1667         2006
# 0               100         2005
# 0                75         2004
# 0           41.9355         2003

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'VLSI Design']
    exec ("file_%s= f" % (i))

# %%
vlsi=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Embedded Systems']
    exec ("file_%s= f" % (i))

# %%
embedded=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Embedded & Wireless Technologies']
    exec ("file_%s= f" % (i))

# %%
embedded_wireless=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Computing Technologies & Virtualization']
    exec ("file_%s= f" % (i))

# %%
computing=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Information Science']
    exec ("file_%s= f" % (i))

# %%
information_science=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Embedded & Instrumentation Engg']
    exec ("file_%s= f" % (i))

# %%
embedded_instrumentation=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Automotive Embedded Systems']
    exec ("file_%s= f" % (i))

# %%
automotive=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'VLSI System Design & Verification']
    exec ("file_%s= f" % (i))

# %%
vlsi_sys=pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Embedded Systems - BE/Btech Grad']
    exec ("file_%s= f" % (i))

# %%
embedded_btech = pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'Embedded Systems - BCA/BSc Grad']
    exec ("file_%s= f" % (i))

# %%
embedded_bca = pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'IT Management']
    exec ("file_%s= f" % (i))

# %%
it_management = pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'MSc DDES (Jan - July)']
    exec ("file_%s= f" % (i))

# %%
Msc_ddes = pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'MSc Info. Science (Jan - July)']
    exec ("file_%s= f" % (i))

# %%
Msc_info_sc = pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
s=[]
for i in range(1,14):
    f='df{}'.format(i)
    f= eval(f)
    f=f.loc[f['Branches'] == 'VLSI CAD']
    exec ("file_%s= f" % (i))

# %%
vlsi_cad = pd.concat([file_1,file_2,file_3,file_4,file_5,file_6,file_7,file_8,file_9,file_10,file_11,file_12,file_13],axis=0,join='inner')

# %%
vlsi_cad = vlsi_cad.reset_index(drop=True)
vlsi_cad
# Out:
#    Branches Class Strength_1 # of placed students_1 Class Strength_8  \
# 0  VLSI CAD                2                      2               41
# 1  VLSI CAD                6                      4               40
# 2  VLSI CAD                6                      4               40
# 3  VLSI CAD                7                      2               16
# 4  VLSI CAD                6                      6               39
# 5  VLSI CAD                7                      3               29
# 6  VLSI CAD                6                      4               27
# 7  VLSI CAD                2                      2               25
# 8  VLSI CAD               10                      5               19
#
#   # of placed students_8 Class Strength # of placed students  \
# 0                     37             43                   39
# 1                     37             46                   41
# 2                     30             46                   34
# 3                     10             23                   12
# 4                     17             45                   23
# 5                     26             36                   29
# 6                     19             33                   23
# 7                     20             27                   22
# 8                     15             29                   20
#
#   Total placement %  year_intake
# 0           90.6977         2011
# 1           89.1304         2010
# 2            73.913         2009
# 3           52.1739         2008
# 4           51.1111         2007
# 5           80.5556         2006
# 6            69.697         2005
# 7           81.4815         2004
# 8           68.9655         2003

# %%
from nvd3 import multiBarChart
import nvd3
nvd3.ipynb.initialize_javascript()

from IPython.core.display import display, HTML
# Out:
# loaded nvd3 IPython extension
# run nvd3.ipynb.initialize_javascript() to set up the notebook
# help(nvd3.ipynb.initialize_javascript) for options
# <link media="all" href="files/nv.d3.css" type="text/css"
#                         rel="stylesheet"/>
# <script src="files/d3.v3.js"></script>
# <script src="files/nv.d3.js"></script>

# %%
chart = multiBarChart(width=1200, height=500, x_axis_format=None)
#xdata = list(vlsi_cad['year_intake'])
xdata = ['VLSI_CAD2011', 'VLSI_CAD2010', 'VLSI_CDA2009', 'VLSI_CAD2008', 'VLSI_CAD2007', 'VLSI_CAD2006', 'VLSI_CAD2005', 'VLSI_CAD2004', 'VLSI_CAD2003']
#ydata1 = list(vlsi_cad['Class Strength'])
ydata1 = [43, 46, 46, 23, 45, 36, 33, 27, 29]
#ydata2 = list(vlsi_cad['# of placed students'])
ydata2 = [39, 41, 34, 12, 23, 29, 23, 22, 20]

chart.add_serie(name="class strength", y=ydata1, x=xdata)
chart.add_serie(name="placed students", y=ydata2, x=xdata)
chart.buildhtml()
display(HTML(chart.htmlcontent))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.1/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.1/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="multibarchart"><svg style="width:1200px;height:500px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_multibarchart=[{"values": [{"y": 43, "x": "VLSI_CAD2011"}, {"y": 46, "x": "VLSI_CAD2010"}, {"y": 46, "x": "VLSI_CDA2009"}, {"y": 23, "x": "VLSI_CAD2008"}, {"y": 45, "x": "VLSI_CAD2007"}, {"y": 36, "x": "VLSI_CAD2006"}, {"y": 33, "x": "VLSI_CAD2005"}, {"y": 27, "x": "VLSI_CAD2004"}, {"y": 29, "x": "VLSI_CAD2003"}], "yAxis": "1", "key": "class strength"}, {"values": [{"y": 39, "x": "VLSI_CAD2011"}, {"y": 41, "x": "VLSI_CAD2010"}, {"y": 34, "x": "VLSI_CDA2009"}, {"y": 12, "x": "VLSI_CAD2008"}, {"y": 23, "x": "VLSI_CAD2007"}, {"y": 29, "x": "VLSI_CAD2006"}, {"y": 23, "x": "VLSI_CAD2005"}, {"y": 22, "x": "VLSI_CAD2004"}, {"y": 20, "x": "VLSI_CAD2003"}], "yAxis": "1", "key": "placed students"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#         chart.xAxis.rotateLabels(0)
#
#         var datum = data_multibarchart;
#
#
#
#
#
#             chart.yAxis
#                 .tickFormat(d3.format(',.2f'));
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#
#         d3.select('#multibarchart svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', '1200')
#             .attr('height', 500)
#             .call(chart);
#
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %%
list(df1['Branches'])
list(df1['Total placement %'])
# Out:
# [75,
#  63.1578947368421,
#  77.5510204081633,
#  77.7777777777778,
#  80,
#  100,
#  100,
#  100,
#  73.5537190082645,
#  77.7777777777778]

# %%
from nvd3 import pieChart
chart = pieChart(name='pieChart', color_category='category20c',
                 height=700, width=700)

xdata = ['Medical Software',
 'VLSI Design',
 'Embedded Systems',
 'Embedded & Wireless Technologies',
 'Computing Technologies & Virtualization',
 'Information Science',
 'Embedded & Instrumentation Engg',
 'Automotive Embedded Systems',
 'All branch without ESIGELEC',
 'All branches']
ydata = [75,63.15,77.53,77.78,80,100,100,100,73.55,77.78]

extra_serie = {"tooltip": {"y_start": "", "y_end": " per"}}
chart.add_serie(y=ydata, x=xdata, extra=extra_serie)
chart.buildhtml()
display(HTML(chart.htmlcontent))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.1/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.1/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="piechart"><svg style="width:700px;height:700px;"></svg></div>
#
#
#     <script>
#
#
#
#     data_piechart=[{"values": [{"label": "Medical Software", "value": 75}, {"label": "VLSI Design", "value": 63.15}, {"label": "Embedded Systems", "value": 77.53}, {"label": "Embedded & Wireless Technologies", "value": 77.78}, {"label": "Computing Technologies & Virtualization", "value": 80}, {"label": "Information Science", "value": 100}, {"label": "Embedded & Instrumentation Engg", "value": 100}, {"label": "Automotive Embedded Systems", "value": 100}, {"label": "All branch without ESIGELEC", "value": 73.55}, {"label": "All branches", "value": 77.78}], "key": "Serie 1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.pieChart();
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#         var datum = data_piechart[0].values;
#
#         chart.color(d3.scale.category20c().range());
#
#     chart.tooltipContent(function(key, y, e, graph) {
#           var x = String(key);
#               var y =  String(y)  + ' per';
#
#               tooltip_str = '<center><b>'+x+'</b></center>' + y;
#               return tooltip_str;
#               });
#         chart.showLabels(true);
#
#             chart.donut(false);
#
#     chart.showLegend(true);
#
#
#
#
#         chart
#             .x(function(d) { return d.label })
#             .y(function(d) { return d.value });
#
#         chart.width(700);
#
#         chart.height(700);
#
#
#             d3.select('#piechart svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', '700')
#             .attr('height', 700)
#             .call(chart);
#
#
#
#         });
#
#
#
#     </script>
#
#     </body>
# </html>

# %%
ydata2
# Out:
# [39, 41, 34, 12, 23, 29, 23, 22, 20]

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = 'Medical Software','VLSI Design','Embedded Systems','Embedded & Wireless Technologies','Computing Technologies & Virtualization','Information Science','Embedded & Instrumentation Engg','Automotive Embedded Systems','All branch without ESIGELEC','All branches'
sizes = [75,63.15,77.5510204081633,77.7777777777778,80,100,100,100,73.5537190082645,77.7777777777778]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','pink','darkblue','white','yellow','red','lightgreen']
#explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
s=[]
p=[]

# %%
for i in range(1,104):
        s.append(eval('set(enroll_{}["Branch"])'.format(i)))
        p.append(eval('len(enroll_{})'.format(i)))

# %%
s=pd.DataFrame(s)
p=pd.DataFrame(p)

s=s.rename(columns={0:'Branch'})
p=p.rename(columns={0:'Enrollments'})

# %%
length_tables=pd.concat([s,p],axis=1)

# %%
length_tables
# Out:
#                                           Branch  Enrollments
# 0                                   MS Ecommerce           31
# 1                                   MS Ecommerce           11
# 2                                   MS Ecommerce           24
# 3                                   MS Ecommerce            5
# 4                                   MS Ecommerce            5
# 5                            MS MEDICAL SOFTWARE           15
# 6                            MS MEDICAL SOFTWARE           10
# 7                            MS MEDICAL SOFTWARE           10
# 8                            MS MEDICAL SOFTWARE            7
# 9                            MS MEDICAL SOFTWARE           17
# 10                           MS MEDICAL SOFTWARE           15
# 11                           MS MEDICAL SOFTWARE            5
# 12                           MS MEDICAL SOFTWARE           16
# 13                           MS MEDICAL SOFTWARE           16
# 14                           MS MEDICAL SOFTWARE            6
# 15                           MS MEDICAL SOFTWARE           10
# 16                           MS MEDICAL SOFTWARE           12
# 17                           MS MEDICAL SOFTWARE           23
# 18                           MS MEDICAL SOFTWARE            7
# 19                           MS MEDICAL SOFTWARE           18
# 20                           MS MEDICAL SOFTWARE            2
# 21                           MS MEDICAL SOFTWARE           25
# 22                           MS MEDICAL SOFTWARE           10
# 23                           MS MEDICAL SOFTWARE           26
# 24                           MS MEDICAL SOFTWARE            5
# 25                           MS MEDICAL SOFTWARE           30
# 26                           MS MEDICAL SOFTWARE           22
# 27                                   MS VLSI-CAD           11
# 28                                   MS VLSI-CAD            7
# 29                                   MS VLSI-CAD           13
# ..                                           ...          ...
# 73            MS Embedded & Wireless Technology            30
# 74                                 MS VLSI-AXIOM            8
# 75                                 MS VLSI-AXIOM           15
# 76                                 MS VLSI-AXIOM           11
# 77                                MS DUAL DEGREE            9
# 78                                MS DUAL DEGREE           20
# 79                                MS DUAL DEGREE           19
# 80                                         MS IT           15
# 81                                         MS IT           16
# 82   MS Computing Technologies & Virtualization            24
# 83                           MS DUAL - LU & ENU             9
# 84                    MSc Tech Embedded Systems            37
# 85                        MSc Tech VLSI DESIGN             11
# 86                      PG DIPLOMA IN E-COMMERCE            5
# 87              BACHELOR OF COMPUTER APPLICATION            6
# 88              BACHELOR OF COMPUTER APPLICATION            5
# 89              BACHELOR OF COMPUTER APPLICATION            8
# 90         MSc DIGITAL DESIGN & EMBEDDED SYSTEMS           20
# 91         MSc DIGITAL DESIGN & EMBEDDED SYSTEMS           12
# 92         MSc DIGITAL DESIGN & EMBEDDED SYSTEMS           12
# 93         MSc DIGITAL DESIGN & EMBEDDED SYSTEMS           14
# 94         MSc DIGITAL DESIGN & EMBEDDED SYSTEMS            7
# 95         MSc DIGITAL DESIGN & EMBEDDED SYSTEMS            8
# 96         MSc DIGITAL DESIGN & EMBEDDED SYSTEMS            5
# 97                       MSc INFORMATION SCIENCE            4
# 98                       MSc INFORMATION SCIENCE            7
# 99                       MSc INFORMATION SCIENCE            6
# 100                      MSc INFORMATION SCIENCE            9
# 101                      MSc INFORMATION SCIENCE            8
# 102                      MSc INFORMATION SCIENCE           20
#
# [103 rows x 2 columns]

# %%
length_tables.to_csv('length_tables.csv')

# %%
import matplotlib.pyplot as plt

# The slices will be ordered and plotted counter-clockwise.
labels = 'MS Ecommerce','MS MEDICAL SOFTWARE','MS VLSI-CAD','MS EMBEDDED SYSTEMS','MS Embedded & Wireless Technology','MS VLSI-AXIOM','MS DUAL DEGREE','MSc DIGITAL DESIGN & EMBEDDED SYSTEMS','MSc INFORMATION SCIENCE'
sizes = [76,307,429,848,75,34,48,78,60]
colors = ['yellow', 'lightskyblue', 'lightcoral','blue','gold','white','green','red','orange']
explode = (0, 0, 0, 0,0,0,0,0,0)  # explode a slice if required

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)
        
#draw a circle at the center of pie to make it look like a donut
centre_circle = plt.Circle((0,0),0.75,color='black', fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)


# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.show()

# %%
import re
for i in range(1,105):
    print(eval("enroll_{}.replace(['KAN', 'KEL', 'DEL', 'TAM', 'WB', 'AP', 'UP', 'MAHE', 'MAHAR', 'ORIS', 'RAJ', 'GUJ', 'MP'],['KARNATAKA', 'KERALA', 'DELHI', 'TAMILNADU', 'WEST BENGAL', 'ANDHRA PRADESH', 'UTTARPRADESH', 'MAHARASHTRA', 'MAHARASHTRA', 'ORISSA', 'RAJASTHAN', 'GUJRAT', 'MADHYAPRADESH'] , regex=True)".format(i)))
# Out:
#       ROLL NO                          NAME Gender           State  \
# NO
# 1   991073001  RAJASTHANESH SHENOY UDYAVARA      M       KARNATAKA
# 2   991073002       PADMANDHRA PRADESHRASAD      M       KARNATAKA
# 3   991073003               LINDA ANNE PAUL      F          KERALA
# 4   991073004                SNIGDHA SAXENA      F           DELHI
# 5   991073005           A GANESH SUBRAMANYA      M          KERALA
# 6   991073006              SUDHESH D KAMATH      M       KARNATAKA
# 7   991073007                    SULAKSHANA      F       KARNATAKA
# 8   991073008                     PRADEEP N      M       KARNATAKA
# 9   991073009              KARUNAKARA RAI B      M       KARNATAKA
# 10  991073010               GOPALAKRISHNA K      M       KARNATAKA
# 11  991073011                SHREELATHA K V      F  ANDHRA PRADESH
# 12  991073012              M KRISHNA PRASAD      M       KARNATAKA
# 13  991073013          PRIYESH KARNATAKANAN      M          KERALA
# 14  991073014           R BRIJESH PRABHAKAR      M       TAMILNADU
# 15  991073015                     ASHA PAUL      F          KERALA
# 16  991073016          ELMA CLARABELL SOANS      F       KARNATAKA
# 17  991073017             ASHUTHOSH RUSTOGI      M           DELHI
# 18  991073018   G SEETHARAM GUTTARPRADESHTA      M  ANDHRA PRADESH
# 19  991073019            VIJAYA KRISHNA M R      M             KAR
# 20  991073020                       VINOD A      M          KERALA
# 21  991073021              JOJO VITHAYATHIL      M          KERALA
# 22  991073022                     TOM TILLO      M          KERALA
# 23  991073023               JIMJEES ABRAHAM      M          KERALA
# 24  991073024              JEITENDER BHATIA      M           DELHI
# 25  991073025                KALPANA SHARMA      F           DELHI
# 26  991073026                V LAKSHMI KALA      F  ANDHRA PRADESH
# 27  991073027              MADHURA NAVADA P      F       KARNATAKA
# 28  991073028                  BHASKAR GOSH      M     WEST BENGAL
# 29  991073029      SHETTY MANOJ BALAKRISHNA      M       KARNATAKA
# 30  991073030                ASHOK R SHETTY      M       KARNATAKA
# 31  991073031          B RAGHAVENDRA AITHAL      M       KARNATAKA
#
#                     Year    Batch        Branch
# NO
# 1   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 2   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 3   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 4   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 5   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 6   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 7   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 8   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 9   Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 10  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 11  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 12  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 13  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 14  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 15  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 16  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 17  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 18  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 19  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 20  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 21  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 22  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 23  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 24  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 25  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 26  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 27  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 28  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 29  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 30  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
# 31  Aug 1999 to Feb 2001  Batch_1  MS Ecommerce
#       ROLL NO                     NAME Gender           State  \
# NO
# 1   991073032        RAJASTHANEENA K L      F          KERALA
# 2   991073033               B S VIKRAM      M  ANDHRA PRADESH
# 3   991073034                V SHANTHI      F       TAMILNADU
# 4   991073035  ANANTHA PADMANABHA BHAT      M       KARNATAKA
# 5   991073036       NARASIMHA KAMATH H      M       KARNATAKA
# 6   991073037           LYNN KURIAKOSE      F          KERALA
# 7   991073038           JYOTHSNA RAI K      F       KARNATAKA
# 8   991073039                  SANOJ R      M          KERALA
# 9   991073040             JAYASIMHAN A      M       KARNATAKA
# 10  991073041          KISHORE KUMAR T      M  ANDHRA PRADESH
# 11  991073042             SUDEEP KUMAR      M    UTTARPRADESH
#
#                      Year    Batch        Branch
# NO
# 1    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 2    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 3    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 4    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 5    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 6    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 7    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 8    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 9    Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 10   Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
# 11   Feb 2000 to Aug 2001  Batch_2  MS Ecommerce
#       ROLL NO                     NAME Gender           State  \
# NO
# 1   001073001            AJAI VARGHESE      M          KERALA
# 2   001073002                MOHAN A Y      M       KARNATAKA
# 3   001073003        NATARAJASTHANAN C      M       TAMILNADU
# 4   001073004        BINURAJASTHAN K R      M          KERALA
# 5   001073005       RAJASTHANIV SHARMA      M    UTTARPRADESH
# 6   001073006          W G JOHN CALVIN      M          KERALA
# 7   001073007              BHAVANI V R      F       KARNATAKA
# 8   001073008  CHANDRA SEKHAR PALADUGU      M  ANDHRA PRADESH
# 9   001073010  C NAVODAYA KUMAR REDDY       M  ANDHRA PRADESH
# 10  001073011      GURURAJASTHAN HEGDE      M       KARNATAKA
# 11  001073013          STEEVAN D'SOUZA      M       KARNATAKA
# 12  001073014        YEDDALA MUNEENDRA      M  ANDHRA PRADESH
# 13  001073016              AMIT KHANNA      M           DELHI
# 14  001073017               PRAMOD K P      M       KARNATAKA
# 15  001073018           PUNITA GIROTRA      F           DELHI
# 16  001073019  ATIN KANDHRA PRADESHOOR      M           DELHI
# 17  001073020          ABBAS ZIYAD P R      M       KARNATAKA
# 18  001073021             S MANJUNATHA      M       KARNATAKA
# 19  001073022    VIVEKARNATAKAANDA R N      M       KARNATAKA
# 20  001073023           GANESH BHATT A      M       KARNATAKA
# 21  001073024         CH KAMESHWAR RAO      M  ANDHRA PRADESH
# 22  001073025       KALAGARA VIDYADHAR      M  ANDHRA PRADESH
# 23  001073026            SAMEER MISHRA      M           BIHAR
# 24  001073027         S VENKAT KRISHNA      M  ANDHRA PRADESH
#
#                     Year    Batch        Branch
# NO
# 1   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 2   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 3   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 4   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 5   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 6   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 7   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 8   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 9   Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 10  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 11  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 12  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 13  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 14  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 15  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 16  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 17  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 18  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 19  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 20  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 21  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 22  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 23  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
# 24  Aug 2000 to Feb 2002  Batch_3  MS Ecommerce
#       ROLL NO                  NAME Gender        State                  Year  \
# NO
# 1   001073028              SREEJU S      M       KERALA  Feb 2001 to Aug 2002
# 2   001073029          DEEPAK RAO B      M    KARNATAKA  Feb 2001 to Aug 2002
# 3   001073030       BIBHOOTHI KUMAR      M  WEST BENGAL  Feb 2001 to Aug 2002
# 4   001073031                RAKESH      M    KARNATAKA  Feb 2001 to Aug 2002
# 5   001073032  SATHYENDRANATH MALLI      M    KARNATAKA  Feb 2001 to Aug 2002
#
#       Batch        Branch
# NO
# 1   Batch_4  MS Ecommerce
# 2   Batch_4  MS Ecommerce
# 3   Batch_4  MS Ecommerce
# 4   Batch_4  MS Ecommerce
# 5   Batch_4  MS Ecommerce
#       ROLL NO                 NAME Gender           State  \
# NO
# 1   011003002       CHANDAN CHETAN      M     WEST BENGAL
# 2   011003003  MANISH KUMAR MISHRA      M           BIHAR
# 3   011003004     CH CHAMUNDESWARI      F  ANDHRA PRADESH
# 4   011003005            V KISHORE      M  ANDHRA PRADESH
# 5   011003006     SUDHANSU SHEKHAR      M     WEST BENGAL
#
#                     Year    Batch        Branch
# NO
# 1   Aug 2001 to Feb 2003  Batch_5  MS Ecommerce
# 2   Aug 2001 to Feb 2003  Batch_5  MS Ecommerce
# 3   Aug 2001 to Feb 2003  Batch_5  MS Ecommerce
# 4   Aug 2001 to Feb 2003  Batch_5  MS Ecommerce
# 5   Aug 2001 to Feb 2003  Batch_5  MS Ecommerce
#       ROLL NO                                   NAME Gender  \
# NO
# 1   981072001                       RAJASTHANENDRA K      M
# 2   981072002                           SANJAY RAO H      M
# 3   981072003                              SUNIL H R      M
# 4   981072004                                VEENA T      F
# 5   981072005                         SUVARDHANA B Y      M
# 6   981072006                       KESHAV MOORTHY C      M
# 7   981072007                CECELIA SHALINI D'SOUZA      F
# 8   981072008                          YOGISH MALLYA      M
# 9   981072009                         AMITA B KAMATH      F
# 10  981072010                             DEEDHITI K      F
# 11  981072011              ANANTHAKRISHNA MADHYASTHA      M
# 12  981072012                        S SHIVASHANKARI      M
# 13  981072013                     NARENDRA KUMAR S G      M
# 14  981072014  LLOYD DEVANDHRA PRADESHRASAD JATHANA       M
# 15  981072015    TRESSA JOSEPH ANTHRANDHRA PRADESHER      F
#
#                 State                  Year    Batch               Branch
# NO
# 1           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 2           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 3           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 4           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 5           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 6           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 7           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 8           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 9           KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 10  MAHARASHTRAASHTRA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 11          KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 12          TAMILNADU  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 13          KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 14          KARNATAKA  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
# 15          TAMILNADU  Aug 1998 to Feb 2000  Batch_1  MS MEDICAL SOFTWARE
#       ROLL NO                              NAME Gender           State  \
# NO
# 1   981072016                    ALVINA D'SILVA      F       KARNATAKA
# 2   981072017                   VARMA VINITHA R      F          KERALA
# 3   981072018                    SHRIDHAR NAYAK      M       KARNATAKA
# 4   981072019             RACHUR VENKATA KRIRAN      M  ANDHRA PRADESH
# 5   981072020                      JEOSPH JOY K      M          KERALA
# 6   981072021                   SUNOOP V THOMAS      M          KERALA
# 7   981072022                   RANJAN V MALLYA      M       KARNATAKA
# 8   981072023                      C ARUN KUMAR      M       KARNATAKA
# 9   981072024  ANNAMMARAJASTHANU RAVI BHARADWAJ      M  ANDHRA PRADESH
# 10  981072025                DALESH S SHARAMSHI      M     MAHARASHTRA
#
#                     Year    Batch               Branch
# NO
# 1   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 2   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 3   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 4   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 5   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 6   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 7   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 8   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 9   Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
# 10  Feb 1999 to Aug 2000  Batch_2  MS MEDICAL SOFTWARE
#       ROLL NO                        NAME Gender      State  \
# NO
# 1   991072001           S KAVITA BHANDARY      F  KARNATAKA
# 2   991072002  ANDHRA PRADESHARNA D NAYAK      F  KARNATAKA
# 3   991072003               RAKESH P NAIK      M  KARNATAKA
# 4   991072004     B S PRASHANTH RAM KUMAR      M  KARNATAKA
# 5   991072005                PRATHEWSHA K      F     KERALA
# 6   991072006                C ANAND SAJU      M     KERALA
# 7   991072007        SWANDHRA PRADESHNA A      F  KARNATAKA
# 8   991072008             HARIKRISHNA G N      M  KARNATAKA
# 9   991072009    SAMEER NARAYAN NAVARATNA      M  KARNATAKA
# 10  991072010                 AMIT SAXENA      M      DELHI
#
#                     Year    Batch               Branch
# NO
# 1   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 2   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 3   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 4   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 5   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 6   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 7   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 8   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 9   Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
# 10  Aug 1999 to Feb 2001  Batch_3  MS MEDICAL SOFTWARE
#       ROLL NO                      NAME Gender      State  \
# NO
# 1   001072006              SWAROOPA J S      F  KARNATAKA
# 2   001072004             PRAVEEN KUMAR      M  KARNATAKA
# 3   001072007    JAYARAJASTHAN PRABHU P      M  KARNATAKA
# 4   001072009  JASON CHETAN O RODRIGUES      M  KARNATAKA
# 5   001072005                S SRIPRIYA      F  TAMILNADU
# 6   001072001                  HARSHA R      M  TAMILNADU
# 7   001072003         PREETHISH KUMAR M      M  TAMILNADU
#
#                     Year    Batch               Branch
# NO
# 1   Aug 2000 to Feb 2002  Batch_4  MS MEDICAL SOFTWARE
# 2   Aug 2000 to Feb 2002  Batch_4  MS MEDICAL SOFTWARE
# 3   Aug 2000 to Feb 2002  Batch_4  MS MEDICAL SOFTWARE
# 4   Aug 2000 to Feb 2002  Batch_4  MS MEDICAL SOFTWARE
# 5   Aug 2000 to Feb 2002  Batch_4  MS MEDICAL SOFTWARE
# 6   Aug 2000 to Feb 2002  Batch_4  MS MEDICAL SOFTWARE
# 7   Aug 2000 to Feb 2002  Batch_4  MS MEDICAL SOFTWARE
#       ROLL NO                                        NAME Gender  \
# NO
# 1   011001007                               PRATHIBHA A M      F
# 2   011001015                           EEDA SHILPANJALI       F
# 3   011001016                             MANNE ASHALATHA      F
# 4   011001009               SRIKARNATAKATH REDDY BHAVANAM      M
# 5   011001013                VENKATA KIRAN KUMAR PINNELLI      M
# 6   011001014                          DHULIPALLA RAMESH       M
# 7   011001001                          ALOMA PREMITA LOBO      F
# 8   011001003                                 MALVE HEMAN      M
# 9   011001006                              HARIRAM G BHAT      M
# 10  011001008  MANJUNATH SHARANABASANDHRA PRADESHPA GURIK      M
# 11  011001002                               SRINANDHINI K      F
# 12  011001010                        K SWANDHRA PRADESHNA      F
# 13  011001011                     ELIMA SUGUNAN ARUKETTIL      F
# 14  011001012                                   SHYMA N K      F
# 15  011001004                                TIBOY THOMAS      M
# 16  011001005                                      ANIL V      M
# 17  011001017                             JAYACHANDRA M R      M
#
#              State                  Year    Batch               Branch
# NO
# 1   ANDHRA PRADESH  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 2   ANDHRA PRADESH  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 3   ANDHRA PRADESH  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 4   ANDHRA PRADESH  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 5   ANDHRA PRADESH  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 6   ANDHRA PRADESH  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 7        KARNATAKA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 8        KARNATAKA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 9        KARNATAKA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 10       KARNATAKA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 11          KERALA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 12          KERALA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 13          KERALA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 14          KERALA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 15          KERALA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 16          KERALA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
# 17          KERALA  Aug 2001 to Feb 2003  Batch_5  MS MEDICAL SOFTWARE
#       ROLL NO                          NAME Gender           State  \
# NO
# 1   011001023           C PAVAN KUMAR REDDY      M  ANDHRA PRADESH
# 2   011001024      SEKHARAMANTRI UDAY KIRAN      M  ANDHRA PRADESH
# 3   011001018                    DIANA PAUL      F       KARNATAKA
# 4   011001020                     SUNITHA R      F       KARNATAKA
# 5   011001021                      SHILPA H      F       KARNATAKA
# 6   011001025  SUSHMA S KASHYANDHRA PRADESH      F       KARNATAKA
# 7   011001027                      SWETHA T      F       KARNATAKA
# 8   011001028               CHITRA PRABHU M      F       KARNATAKA
# 9   011001032                ARCHANA MURTHY      F       KARNATAKA
# 10  011001019              S SRIKARNATAKATH      M       KARNATAKA
# 11  011001030         MANOJ KUMAR SINGH M B      M       KARNATAKA
# 12  011001034                   PRADEEP R P      M       KARNATAKA
# 13  011001029                   B KATYAYANI      F          KERALA
# 14  011001031             ELAVAAR KUZHALI S      F          KERALA
# 15  011001033             DEEPA PRABHAKARAN      F       TAMILNADU
#
#                     Year    Batch               Branch
# NO
# 1   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 2   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 3   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 4   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 5   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 6   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 7   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 8   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 9   Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 10  Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 11  Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 12  Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 13  Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 14  Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
# 15  Feb 2002 to Aug 2003  Batch_6  MS MEDICAL SOFTWARE
#       ROLL NO                  NAME Gender           State  \
# NO
# 1   021001004   RAMAKARNATAKATH V R      M  ANDHRA PRADESH
# 2   021001007  A BHARGAVI HARIPRIYA      F       KARNATAKA
# 3   021001002       PRASHANTA KUMAR      M       KARNATAKA
# 4   021001001       SUKHAS R SHENOI      M          KERALA
# 5   021001009            VANI V RAO      F            LEFT
#
#                     Year    Batch               Branch
# NO
# 1   Aug 2002 to Feb 2004  Batch_7  MS MEDICAL SOFTWARE
# 2   Aug 2002 to Feb 2004  Batch_7  MS MEDICAL SOFTWARE
# 3   Aug 2002 to Feb 2004  Batch_7  MS MEDICAL SOFTWARE
# 4   Aug 2002 to Feb 2004  Batch_7  MS MEDICAL SOFTWARE
# 5   Aug 2002 to Feb 2004  Batch_7  MS MEDICAL SOFTWARE
#       ROLL NO                              NAME Gender           State  \
# NO
# 1   021001011                      S SRILAKSHMI      F  ANDHRA PRADESH
# 2   021001015  NG REDDY ANNANDHRA PRADESHAREDDY      M  ANDHRA PRADESH
# 3   021001023         JAGATH INDUTTARPRADESHURU      M  ANDHRA PRADESH
# 4   021001025            KRISHNA KISHORE PARIMI      M  ANDHRA PRADESH
# 5   021001010                       JOY LAVINYA      F       KARNATAKA
# 6   021001016                        SHEELA S N      F       KARNATAKA
# 7   021001017                         N PREETHI      F       KARNATAKA
# 8   021001014                    DINESH KUMAR V      M       KARNATAKA
# 9   021001024                     MALANCHA HORE      M       KARNATAKA
# 10  021001026                       HARISHA R V      M       KARNATAKA
# 11  021001027           SUNILKUMAR M TEGGIHALLI      M       KARNATAKA
# 12  021001018                     SINDHU MATHEW      F          KERALA
# 13  021001019               MANOHAR NARAYAN R K      M            LEFT
# 14  021001012                          SUBASH G      M       TAMILNADU
# 15  021001013                           ASHOK B      M       TAMILNADU
# 16  021001020               K H NAVEEN CHANDRAN      M       TAMILNADU
#
#                     Year    Batch               Branch
# NO
# 1   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 2   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 3   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 4   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 5   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 6   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 7   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 8   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 9   Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 10  Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 11  Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 12  Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 13  Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 14  Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 15  Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
# 16  Feb 2003 to Feb 2005  Batch_8  MS MEDICAL SOFTWARE
#       ROLL NO                         NAME Gender        State  \
# NO
# 1   031001021       DANETTE LUCY FERNANDES      F    KARNATAKA
# 2   031001004              MOHANDASA NAYAK      M    KARNATAKA
# 3   031001007          SHAIK M A WALIUDDIN      M    KARNATAKA
# 4   031001008          ASHWATH RAJASTHAN M      M    KARNATAKA
# 5   031001013                SRINIDHI H A       M    KARNATAKA
# 6   031001018            PAVITHRARAJASTHAN      M    KARNATAKA
# 7   031001020              MADHUSUDHAN RAO      M    KARNATAKA
# 8   031001022  SANGAMESH MADHUSUDAN GUGWAD      M    KARNATAKA
# 9   031001023         JOYSON ALEX KAIRANNA      M    KARNATAKA
# 10  031001024                KARTIK R BHAT      M    KARNATAKA
# 11  031001026             SANDEEP S SHETTY      M    KARNATAKA
# 12  031001028                     AKHILA P      F       KERALA
# 13  031001019       KURIAKOSE JACOB THOMAS      M       KERALA
# 14  031001027         DOSHI PIYUSH SUBHASH      M  MAHARASHTRA
# 15  031001029                  R VINOTHINI      F    TAMILNADU
# 16  031001002   N C MANIKARNATAKADA PRASAD      M    TAMILNADU
#
#                     Year    Batch               Branch
# NO
# 1   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 2   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 3   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 4   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 5   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 6   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 7   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 8   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 9   Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 10  Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 11  Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 12  Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 13  Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 14  Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 15  Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
# 16  Aug 2003 to Aug 2005  Batch_9  MS MEDICAL SOFTWARE
#       ROLL NO                     NAME Gender           State  \
# NO
# 1   031001032  THANGELLA NARASIMHA RAO      M  ANDHRA PRADESH
# 2   031001031                POOJA S J      F       KARNATAKA
# 3   031001033              RAKSHITA HM      F       KARNATAKA
# 4   031001030    NAZAR MOHAMMED SAMEEM      M          KERALA
# 5   031001035       AJAY RADHAKRISHNAN      M          KERALA
# 6   031001034           MALLIKA DEVI P      F       TAMILNADU
#
#                     Year     Batch               Branch
# NO
# 1   Feb 2004 to Feb 2006  Batch_10  MS MEDICAL SOFTWARE
# 2   Feb 2004 to Feb 2006  Batch_10  MS MEDICAL SOFTWARE
# 3   Feb 2004 to Feb 2006  Batch_10  MS MEDICAL SOFTWARE
# 4   Feb 2004 to Feb 2006  Batch_10  MS MEDICAL SOFTWARE
# 5   Feb 2004 to Feb 2006  Batch_10  MS MEDICAL SOFTWARE
# 6   Feb 2004 to Feb 2006  Batch_10  MS MEDICAL SOFTWARE
#       ROLL NO                          NAME Gender           State  \
# NO
# 1   041001003  CHERUKURI SWANDHRA PRADESHNA      F  ANDHRA PRADESH
# 2   041001006          S KHADERUNNISA BEGUM      F  ANDHRA PRADESH
# 3   041001007               KIRAN KUMAR B R      M  ANDHRA PRADESH
# 4   041001008       ABHISHEK MAHARASHTRAAJU      M  ANDHRA PRADESH
# 5   041001009      CHANDALA SATEESH CHANDRA      M  ANDHRA PRADESH
# 6   041001002              SIDDHANT AGARWAL      M           DELHI
# 7   041001010                  SHASHIKALA S      F       KARNATAKA
# 8   041001001                   SURESHA G N      M       KARNATAKA
# 9   041001005                 KARTHIK K RAO      M       KARNATAKA
# 10  041001004                          SHUA      F          KERALA
#
#                     Year     Batch               Branch
# NO
# 1   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 2   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 3   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 4   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 5   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 6   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 7   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 8   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 9   Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
# 10  Aug 2004 to Aug 2006  Batch_11  MS MEDICAL SOFTWARE
#       ROLL NO                      NAME Gender           State  \
# NO
# 1   051001006     MOHAMMAD ABDUL HAKEEM      M  ANDHRA PRADESH
# 2   051001008   PERLA VIVEKARNATAKAANDA      M  ANDHRA PRADESH
# 3   051001004       SATBIR SINGH BHATTI      M           ASSAM
# 4   051001005             DEEPA I BELVI      F       KARNATAKA
# 5   051001007            TRISHALA BASTI      F       KARNATAKA
# 6   051001002           KIRAN KUMAR K V      M       KARNATAKA
# 7   051001010                 VISHWAS R      M       KARNATAKA
# 8   051001012         SYED ZUHIB AHAMED      M       KARNATAKA
# 9   051001001  KAREMORE GOPAL RAGHUNATH      M     MAHARASHTRA
# 10  051001003            ARUN SHREEDHAR      M          ORISSA
# 11  051001011             ROHIT PALIWAL      M       RAJASTHAN
# 12  051001009               SARANYA N D      F       TAMILNADU
#
#                     Year     Batch               Branch
# NO
# 1   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 2   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 3   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 4   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 5   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 6   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 7   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 8   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 9   Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 10  Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 11  Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
# 12  Aug 2005 to Aug 2007  Batch_12  MS MEDICAL SOFTWARE
#       ROLL NO                         NAME Gender           State  \
# NO
# 1   061001015      PONNAM VENKATA ABHIJEET      M  ANDHRA PRADESH
# 2   061001004                 ABDUR RAHMAN      M     CHATTISGARH
# 3   061001002  HARDIKKUMAR KIRITKUMAR SONI      M          GUJRAT
# 4   061001005                        KIRAN      F         HARYANA
# 5   061001008                     SOWMYA S      F             KAR
# 6   061001009                  ASHWINI L J      F             KAR
# 7   061001012               RASHMI KRISHNA      F             KAR
# 8   061001016            G T VIJAYALAKSHMI      F             KAR
# 9   061001017                    SHALINI J      F             KAR
# 10  061001018                 UMALAKSHMI A      F             KAR
# 11  061001020              PUSHPALATHA B G      F             KAR
# 12  061001024                  SHWETHA K S      F             KAR
# 13  061001001                SRIVATHSA H H      M             KAR
# 14  061001007             SYED AHMED ULLAH      M             KAR
# 15  061001010             K YATHIRAJASTHAN      M             KAR
# 16  061001011               SHARATH KALYAN      M             KAR
# 17  061001014               RITHADHAMA C S      M             KAR
# 18  061001019              K NAGESWARA RAO      M             KAR
# 19  061001023                M S R DIKSHIT      M             KAR
# 20  061001013                   R SANTHIYA      F       TAMILNADU
# 21  061001022                 POOMATHI S N      F       TAMILNADU
# 22  061001003                    M DIWAKAR      M       TAMILNADU
# 23  061001021      SAURABH GUTTARPRADESHTA      M    UTTARPRADESH
#
#                     Year     Batch               Branch
# NO
# 1   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 2   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 3   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 4   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 5   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 6   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 7   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 8   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 9   Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 10  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 11  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 12  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 13  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 14  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 15  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 16  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 17  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 18  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 19  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 20  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 21  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 22  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
# 23  Aug 2006 to Jul 2008  Batch_13  MS MEDICAL SOFTWARE
#       ROLL NO                       NAME Gender          State  \
# NO
# 1   061001026              DEEPAK KAMBOJ      M        HARYANA
# 2   061001027               SATBIR SINGH      M        HARYANA
# 3   061001031               ANKUR KAMBOJ      M        HARYANA
# 4   061001028               POORVA SETHI      F  MADHYAPRADESH
# 5   061001029                   R JANANI      F      TAMILNADU
# 6   061001030        DIVYA SHRINIVAS RAO      F            KAR
# 7   061001032  RASHMI VIJAYEENDRA KARJOL      F            KAR
#
#                     Year     Batch               Branch
# NO
# 1   Jan 2007 to Dec 2008  Batch_14  MS MEDICAL SOFTWARE
# 2   Jan 2007 to Dec 2008  Batch_14  MS MEDICAL SOFTWARE
# 3   Jan 2007 to Dec 2008  Batch_14  MS MEDICAL SOFTWARE
# 4   Jan 2007 to Dec 2008  Batch_14  MS MEDICAL SOFTWARE
# 5   Jan 2007 to Dec 2008  Batch_14  MS MEDICAL SOFTWARE
# 6   Jan 2007 to Dec 2008  Batch_14  MS MEDICAL SOFTWARE
# 7   Jan 2007 to Dec 2008  Batch_14  MS MEDICAL SOFTWARE
#       ROLL NO                                               NAME Gender  \
# NO
# 1   071001001           POONAM DALAL                                  F
# 2   071001002     PRABHA RAJASTHANU                                   F
# 3   071001003           AMAR DEEP JAISWAL                             M
# 4   071001004           AJIT PAL SINGH                                M
# 5   071001005  MAHARASHTRAASHTRASH M                         ...      M
# 6   071001006           B BALAJI                                      M
# 7   071001007  K JAYANDHRA PRADESHRAKASH                     ...      M
# 8   071001009           DEEPAK R                                      M
# 9   071001010           MANJARI SHARMA                                F
# 10  071001011           PRIDA THABAH                                  F
# 11  071001012           MANJU ANN THOMAS                              F
# 12  071001013           PRIYANKA JATAIN                               F
# 13  071001014           ARUNA B                                       F
# 14  071001015           UMA SATYA VANI                                F
# 15  071001016           SUDERSHAN KUMAR GOTHWAL                       M
# 16  071001017           VARTUL JAIN                                   M
# 17  071001018           SIDDHARTH S                                   M
# 18  071001019                                        PRADEEP K V      M
#
#              State                   Year     Batch               Branch
# NO
# 1          HARYANA  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 2           KERALA  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 3     UTTARPRADESH  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 4          DELHIHI  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 5         KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 6         KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 7         KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 8         KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 9     UTTARPRADESH  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 10       MEGHALAYA  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 11          KERALA  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 12         HARYANA  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 13        KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 14  ANDHRA PRADESH  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 15        KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 16   MADHYAPRADESH  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 17        KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
# 18        KARNATAK  Aug 2007 to July 2009  Batch_15  MS MEDICAL SOFTWARE
#       ROLL NO                  NAME Gender     State                  Year  \
# NO
# 1   071001020                ASHISH      M  KARNATAK  Jan 2008 to Dec 2009
# 2   071001021  RAJASTHANESH BISHNOI      M   HARYANA  Jan 2008 to Dec 2009
#
#        Batch               Branch
# NO
# 1   Batch_16  MS MEDICAL SOFTWARE
# 2   Batch_16  MS MEDICAL SOFTWARE
#        ROLL NO                       NAME Gender           State  \
# NO
# 1    081001001            DILIP BHARADWAJ      M        KARNATAK
# 2    081001002               JOBIN GEORGE      M          KERALA
# 3    081001003              RAVIKIRAN C R      M        KARNATAK
# 4    081001004               BHARATHI K N      F        KARNATAK
# 5    081001005            SWATHI SURESH G      F        KARNATAK
# 6    081001006                  NANDISH S      M        KARNATAK
# 7    081001007                 VIDYA B A-      F        KARNATAK
# 8    081001008               LOKESH MUTHU      M   MADHYAPRADESH
# 9    081001010                    RAHUL N      M        KARNATAK
# 10   081001011                 VARUN GAUR      M    UTTARPRADESH
# 11   081001012             B VIJAYA KUMAR      M  ANDHRA PRADESH
# 12   081001013             VINAY MANURKAR      M   MADHYAPRADESH
# 13   081001014                KEERTHI M S      F        KARNATAK
# 14   081001015       BALAKRISHANA GOKHALE      M   MADHYAPRADESH
# 15   081001016       LAKSHMI SASI KIRAN S      M  ANDHRA PRADESH
# 16   081001017       TEENA MATHEW THOLOOR      F          KERALA
# 17   081001020                VASANTH K S      M        KARNATAK
# 18   081001021            PRAVEEN KUMAR B      M        KARNATAK
# 19   081001022              NAKUL NARAYAN      M          KERALA
# 20   081001023              SANTOSH PATIL      M        KARNATAK
# 21   081001024               NANCY NAGPAL      F         HARYANA
# 22   081001025              NITESH SHARMA      F         HARYANA
# 23   081001026               MAMTA BANSAL      F         HARYANA
# 24   081001027  SOUVIK SENGUTTARPRADESHTA      M     WEST BENGAL
# 25   081001029          RANJEETA ATHAVALE      F        KARNATAK
#
#                      Year     Batch               Branch
# NO
# 1   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 2   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 3   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 4   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 5   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 6   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 7   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 8   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 9   Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 10  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 11  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 12  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 13  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 14  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 15  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 16  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 17  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 18  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 19  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 20  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 21  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 22  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 23  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 24  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
# 25  Aug 2008 to July 2010  Batch_17  MS MEDICAL SOFTWARE
#       ROLL NO                                               NAME Gender  \
# NO
# 1   081001030                                   MEGHA S KULKARNI      F
# 2   081001031           KIRAN PATEEL G.S                              M
# 3   081001032           DEEPTHI C                                     F
# 4   081001033           RIYA HEGDE                                    F
# 5   081001034           PHEBE DANIEL                                  F
# 6   081001035           SHUBHA PRABHAKAR                              F
# 7   081001036  VYAS PRATIKKUMAR MAHARASHTRAASHTRASHKUMAR     ...      M
# 8   081001037           SHIPRA PARIMOO                                F
# 9   081001038                      PATEL GUNJANBHAI NAVNEET BHAT      M
# 10  081001039                                      RAKESH KUMAR       M
#
#         State                  Year     Batch               Branch
# NO
# 1    KARNATAK  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 2    KARNATAK  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 3    KARNATAK  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 4    KARNATAK  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 5   TAMILNADU  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 6    KARNATAK  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 7      GUJRAT  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 8    KARNATAK  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 9      GUJRAT  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
# 10    HARYANA  Jan 2009 to Dec 2010  Batch_18  MS MEDICAL SOFTWARE
#       ROLL NO                                               NAME Gender  \
# NO
# 1   091001001           SWETHA N                                      F
# 2   091001002           LAKSHMISHA THANTRY MG                         M
# 3   091001003           RICHA K K                                     F
# 4   091001005           SANTOSH G                                     M
# 5   091001006  DEEPTHI BANDARUTTARPRADESHALLI                ...      F
# 6   091001008  BANDANDHRA PRADESHPA                          ...      M
# 7   091001011           ASHWINI B S                                   F
# 8   091001012           SIBIN SILVY VARGHESE                          M
# 9   091001013           DIVYASRI K M                                  F
# 10  091001014  AMOL KANDHRA PRADESHOOR                       ...      M
# 11  091001015           PRAVEEN BALKUR                                M
# 12  091001017           UDAY KIRAN R                                  M
# 13  091001018           RAHUL S SRIVATSA                              M
# 14  091001019           ADDEPALLI LAVANYA MURALI                      F
# 15  091001020           P LAVANYA                                     F
# 16  091001021           TANMAY SAHAI                                  M
# 17  091001023           DEEPTHI D                                     F
# 18  091001027           ADITYA SHRIVATRI                              M
# 19  091001029           MITULKUMAR PRAVINKUMAR RAMWANI                M
# 20  091001030  M GANGAM KUSHALANDHRA PRADESHPA               ...      F
# 21  091001031           NARASIMHA K S                                 M
# 22  091001033           SANTHOSH KUMAR H                              M
# 23  091001034           ATISH SISODIA                                 M
# 24  091001036                                     BINDUMATHI H C      F
# 25  091001037                                            KIRAN D      M
# 26  091001039                                     RAGAVENDRA D H      M
#
#                State                 Year     Batch               Branch
# NO
# 1           KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 2           KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 3           KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 4           KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 5     ANDHRA PRADESH  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 6           KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 7           KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 8      MADHYAPRADESH  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 9           KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 10      UTTARPRADESH  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 11          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 12          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 13          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 14  MAHARASHTRASHTRA  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 15          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 16      UTTARPRADESH  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 17          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 18       CHATTISGARH  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 19        GUJRATARAT  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 20          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 21          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 22          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 23     MADHYAPRADESH  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 24          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# 25          KARNATAK  Aug 09 to July 2011  Batch_19  MS MEDICAL SOFTWARE
# ...
# 7   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 8   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 9   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 10  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 11  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 12  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 13  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 14  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
#       ROLL NO                                      NAME Gender  \
# NO
# 1   091007001  M S KARTHIK                                   M
# 2   091007002  HEMANTH KUMAR RN                              M
# 3   091007003  RAGHU K S                                     M
# 4   091007004  MIHIR NIKHIL CHITNIS                          M
# 5   091007006  ARCHANA U                                     F
# 6   091007007  NIKHIL V V                                    M
# 7   091007008                 VISHVANDHRA PRADESHATHI K      M
#
#                 State                   Year    Batch  \
# NO
# 1            KARNATAK  Aug 2009 to July 2011  Batch_5
# 2            KARNATAK  Aug 2009 to July 2011  Batch_5
# 3              KERALA  Aug 2009 to July 2011  Batch_5
# 4   MAHARASHTRAASHTRA  Aug 2009 to July 2011  Batch_5
# 5            KARNATAK  Aug 2009 to July 2011  Batch_5
# 6              KERALA  Aug 2009 to July 2011  Batch_5
# 7                  TN  Aug 2009 to July 2011  Batch_5
#
#                                    Branch
# NO
# 1   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 2   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 3   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 4   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 5   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 6   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 7   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
#       ROLL NO                                            NAME Gender  \
# NO
# 1   101007001           ANAND C MOHAN                              M
# 2   101007002        GIRISH K                                      M
# 3   101007003       M RAJASTHANENDRA BABU                          M
# 4   101007004        SOWNDARYA C                                   F
# 5   101007005        PRASHANTH P                                   M
# 6   101007006        SHABEER ALI M                                 M
# 7   101007008  NIKHIL RAJASTHAN                                    M
# 8   101007009                         SNEHA JOSEPH ALEXANDRIA      F
#
#        State                  Year    Batch  \
# NO
# 1   KARNATAK  Aug 2010 to Jul 2012  Batch_6
# 2   KARNATAK  Aug 2010 to Jul 2012  Batch_6
# 3         TN  Aug 2010 to Jul 2012  Batch_6
# 4   KARNATAK  Aug 2010 to Jul 2012  Batch_6
# 5   KARNATAK  Aug 2010 to Jul 2012  Batch_6
# 6     KERALA  Aug 2010 to Jul 2012  Batch_6
# 7   KARNATAK  Aug 2010 to Jul 2012  Batch_6
# 8   KARNATAK  Aug 2010 to Jul 2012  Batch_6
#
#                                    Branch
# NO
# 1   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 2   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 3   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 4   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 5   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 6   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 7   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 8   MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
#       ROLL NO                 NAME Gender           State  \
# NO
# 1   111007001  PUDARI ANIRUDH GOUD      M  ANDHRA PRADESH
# 2   111007002              RANJANA      F        KARNATAK
# 3   111007003      RAKSHITH SHETTY      M        KARNATAK
# 4   111007005         ABHILASH M R      M        KARNATAK
# 5   111007006         JAYANT KUMAR      M           BIHAR
#
#                     Year    Batch                                 Branch
# NO
# 1   Aug 2011 to Jul 2013  Batch_7  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 2   Aug 2011 to Jul 2013  Batch_7  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 3   Aug 2011 to Jul 2013  Batch_7  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 4   Aug 2011 to Jul 2013  Batch_7  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
# 5   Aug 2011 to Jul 2013  Batch_7  MSc DIGITAL DESIGN & EMBEDDED SYSTEMS
#       ROLL NO                   NAME Gender            State  \
# NO
# 1   051008002      C V KAVIRAJASTHAN      M  ANDHRA PRADESH
# 2   051008004    A V NAGARJUNA REDDY      M  ANDHRA PRADESH
# 3   051008005  NUTTARPRADESHUR KUMAR      F        KARNATAKA
# 4   051008003         K SATISH KUMAR      M        KARNATAKA
#
#                     Year    Batch                   Branch
# NO
# 1   Aug 2005 to Jul 2007  Batch_1  MSc INFORMATION SCIENCE
# 2   Aug 2005 to Jul 2007  Batch_1  MSc INFORMATION SCIENCE
# 3   Aug 2005 to Jul 2007  Batch_1  MSc INFORMATION SCIENCE
# 4   Aug 2005 to Jul 2007  Batch_1  MSc INFORMATION SCIENCE
#       ROLL NO                                       NAME Gender  \
# NO
# 1   061008001                                  ASHWINI B      F
# 2   061008002  NAIK TRUTTARPRADESHTI NAGANDHRA PRADESHPA      F
# 3   061008003                                 RAMYA BHAT      F
# 4   061008004                                   RASHMI        F
# 5   061008005                           MOHAMMAD KHADEER      M
# 6   061008006                                     MAMTAJ      F
# 7   061008007                    MANASH PRATIM BORPUJARI      M
#
#              State                  Year    Batch                   Branch
# NO
# 1         KARNATAK  Aug 2006 to Jul 2008  Batch_2  MSc INFORMATION SCIENCE
# 2         KARNATAK  Aug 2006 to Jul 2008  Batch_2  MSc INFORMATION SCIENCE
# 3         KARNATAK  Aug 2006 to Jul 2008  Batch_2  MSc INFORMATION SCIENCE
# 4         KARNATAK  Aug 2006 to Jul 2008  Batch_2  MSc INFORMATION SCIENCE
# 5   ANDHRA PRADESH  Aug 2006 to Jul 2008  Batch_2  MSc INFORMATION SCIENCE
# 6         KARNATAK  Aug 2006 to Jul 2008  Batch_2  MSc INFORMATION SCIENCE
# 7            ASSAM  Aug 2006 to Jul 2008  Batch_2  MSc INFORMATION SCIENCE
#       ROLL NO                                               NAME Gender  \
# NO
# 1   071008001           NAMITHA KAMATH K                              F
# 2   071008002           POONAM                                        F
# 3   071008005  ANUTTARPRADESHAMA                             ...      F
# 4   071008006                                  AKSHATH RAJASTHAN      M
# 5   071008007           TOMSON M T                                    M
# 6   071008008           DEVAIAH                                       M
#
#        State                  Year    Batch                   Branch
# NO
# 1   KARNATAK  Aug 2007 to Jul 2009  Batch_3  MSc INFORMATION SCIENCE
# 2   KARNATAK  Aug 2007 to Jul 2009  Batch_3  MSc INFORMATION SCIENCE
# 3   KARNATAK  Aug 2007 to Jul 2009  Batch_3  MSc INFORMATION SCIENCE
# 4   KARNATAK  Aug 2007 to Jul 2009  Batch_3  MSc INFORMATION SCIENCE
# 5     KERALA  Aug 2007 to Jul 2009  Batch_3  MSc INFORMATION SCIENCE
# 6   KARNATAK  Aug 2007 to Jul 2009  Batch_3  MSc INFORMATION SCIENCE
#       ROLL NO                                      NAME Gender         State  \
# NO
# 1   081008001  DEEKSHA                                       F      KARNATAK
# 2   081008002  ROY CLAUD ANTONY REBELLO                      M      KARNATAK
# 3   081008003  KARUNESH KUMAR MISHRA                         M  UTTARPRADESH
# 4   081008004  AKSHATHA K R                                  F      KARNATAK
# 5   081008005  PRAMEELA JYOTHI REBERRO                       F      KARNATAK
# 6   081008006  ABHINITH M                                    M      KARNATAK
# 7   081008007  RAO NISHA MUKUND                              F    GUJRATARAT
# 8   081008008  VANISHRI A                                    F      KARNATAK
# 9   081008009  AJITH R SHENOY                                M        KERALA
#
#                     Year    Batch                   Branch
# NO
# 1   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 2   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 3   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 4   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 5   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 6   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 7   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 8   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
# 9   Aug 2008 to Jul 2010  Batch_4  MSc INFORMATION SCIENCE
#       ROLL NO                                      NAME Gender         State  \
# NO
# 1   091008001  REENA RUBY D'SOUZA                            F      KARNATAK
# 2   091008002  SINDHU KAMATH K                               F      KARNATAK
# 3   091008003  SHIKHA KUMARI CHAUHAN                         F         BIHAR
# 4   091008004  RAYAN FRANCIS CRASTO                          M      KARNATAK
# 5   091008005  ANANTHAJITHA                                  M      KARNATAK
# 6   091008006  DEVIPRASAD                                    M      KARNATAK
# 7   091008007  IMRAN M S SOKWALA                             M      TANZANIA
# 8   091008008                                  OM SINGH      M  UTTARPRADESH
#
#                     Year    Batch                   Branch
# NO
# 1   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
# 2   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
# 3   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
# 4   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
# 5   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
# 6   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
# 7   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
# 8   Aug 2009 to Jul 2011  Batch_5  MSc INFORMATION SCIENCE
#       ROLL NO                                        NAME Gender     State  \
# NO
# 1   101008001    SHOBITHA                                      F  KARNATAK
# 2   101008002               AMAR MICHAEL SEQUEIRA              M  KARNATAK
# 3   101008003    JYOTHSNA                                      F        KA
# 4   101008004        PRATHVI J SHETTY                          F  KARNATAK
# 5   101008005                    SOWMYA SHAMBHU SHETTY         F  KARNATAK
# 6   101008006        YAKSHITH H SALIAN                         M  KARNATAK
# 7   101008007          DAINA JOICE OLIVERA                     F  KARNATAK
# 8   101008008           ANISHA RENITA DSILVA                   F  KARNATAK
# 9   101008009         VINITHA TEENA PINTO                      F  KARNATAK
# 10  101008010  MR. KARNATAKAOJ BAISHYA                         M     ASSAM
# 11  101008011         ANGSHUMANDEKA                            M     ASSAM
# 12  101008013    SANDESH T                                     M  KARNATAK
# 13  101008014            MANJUNATHA SHENOY                     M  KARNATAK
# 14  101008015         SHRADDHA SHETTY                          F  KARNATAK
# 15  101008016          RAKSHITH SARALAYA                       M  KARNATAK
# 16  101008017         BRIJESH B POOJARY                        M  KARNATAK
# 17  101008018    SHEIKH MOH RUKNUDDIN RAZA                     M  KARNATAK
# 18  101008019        ANUSHA G SHETTY                           F  KARNATAK
# 19  101008021    SOWMYA BHAT                                   F  KARNATAK
# 20  101008022    SHRUTHI                                       F  KARNATAK
#
#                     Year    Batch                   Branch
# NO
# 1   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 2   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 3   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 4   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 5   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 6   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 7   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 8   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 9   Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 10  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 11  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 12  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 13  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 14  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 15  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 16  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 17  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 18  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 19  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
# 20  Aug 2010 to Jul 2012  Batch_6  MSc INFORMATION SCIENCE
#       ROLL NO                      NAME Gender     State  \
# NO
# 1   111008001                RANJITHA R      F  KARNATAK
# 2   111008002     MANOOR KARTHIK SHENOY      M  KARNATAK
# 3   111008003           POOJA P POOJARY      F  KARNATAK
# 4   111008004            HARSHITA DAGNA      F  KARNATAK
# 5   111008005                 DEEPTHI A      F  KARNATAK
# 6   111008006            HEZIL MENDONCA      F  KARNATAK
# 7   111008007                SHILPA K S      F  KARNATAK
# 8   111008008               SOWMYA SHET      F  KARNATAK
# 9   111008009              UJJWAL KUMAR      M     BIHAR
# 10  111008010  LAVEENA CAROLINE MENEZES      F  KARNATAK
# 11  111008011                  AKSHATHA      F  KARNATAK
# 12  111008013                SHILPA DSA      F  KARNATAK
# 13  111008014                  JYOTHSNA      F  KARNATAK
# 14  111008015                   ASHWINI      F  KARNATAK
# 15  111008016           AKSHATHA SHETTY      F  KARNATAK
# 16  111008017          DHARMENDRA KUMAR      M     BIHAR
# 17  111008018      PRAKASH KUMAR MISHRA      M     BIHAR
#
#                     Year    Batch                   Branch
# NO
# 1   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 2   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 3   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 4   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 5   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 6   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 7   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 8   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 9   Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 10  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 11  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 12  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 13  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 14  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 15  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 16  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE
# 17  Aug 2011 to Jul 2013  Batch_7  MSc INFORMATION SCIENCE

# %%
s=pd.DataFrame()
s["State"] = ""

# %%
for i in range(1,105):
    r=pd.DataFrame(eval("enroll_{}['State'].value_counts()".format(i)))
    s.merge(r,how='left', left_on='State', right_on='State')

# %%
s
# Out:
# Empty DataFrame
# Columns: [State]
# Index: []

# %%
(set(enroll_1['State']))
# Out:
# {'AP', 'DEL', 'KAN', 'KAR', 'KEL', 'TAM', 'WB'}

# %%
enroll_40['State'].value_counts()
# Out:
# AP             12
# KAN            10
# UP              1
# UTTARANCHAL     1
# GOA             1
# KEL             1
# WB              1
# Name: State, dtype: int64
